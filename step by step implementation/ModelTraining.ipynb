# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
root = "/content/drive/MyDrive/MangoSense"
checks = [
"datasets/preprocessed-leaves-dual/train",
"datasets/preprocessed-leaves-dual/val",
"datasets/preprocessed-leaves-dual/test",
"datasets/preprocessed-fruit-dual/train",
"datasets/preprocessed-fruit-dual/val",
"datasets/preprocessed-fruit-dual/test",
]
for c in checks:
    print(c, "->", os.path.isdir(os.path.join(root, c)))
# Out:
# datasets/preprocessed-leaves-dual/train -> True
# datasets/preprocessed-leaves-dual/val -> True
# datasets/preprocessed-leaves-dual/test -> True
# datasets/preprocessed-fruit-dual/train -> True
# datasets/preprocessed-fruit-dual/val -> True
# datasets/preprocessed-fruit-dual/test -> True

# %%
import os
import zipfile

# Define the path to your zip file in Google Drive
# Update this path if your zip file is located elsewhere
zip_path = '/content/drive/MyDrive/MangoSense/split-datasets-2.zip'

# Define the directory where you want to extract the contents
extract_dir = '/content/drive/MyDrive/MangoSense/datasets'

print(f'Checking if zip file exists: {zip_path}')
if not os.path.exists(zip_path):
    print(f'Error: Zip file not found at {zip_path}')
else:
    print(f'Zip file found. Extracting to: {extract_dir}')
    os.makedirs(extract_dir, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as z:
        z.extractall(extract_dir)
    print('Extraction complete!')
# Out:
# Checking if zip file exists: /content/drive/MyDrive/MangoSense/split-datasets-2.zip
# Zip file found. Extracting to: /content/drive/MyDrive/MangoSense/datasets
# Extraction complete!

# %% [markdown]
# Custom Cnn Symptom - Co Attention

# %%
from google.colab import drive
import os, zipfile

drive.mount('/content/drive')

zip_path = '/content/drive/MyDrive/MangoSense/symptom_data.zip'
extract_dir = '/content/drive/MyDrive/MangoSense'

print('Zip exists:', os.path.exists(zip_path))
if not os.path.exists(zip_path):
    raise FileNotFoundError(f'Not found: {zip_path}')

os.makedirs(extract_dir, exist_ok=True)
with zipfile.ZipFile(zip_path, 'r') as z:
    z.extractall(extract_dir)

print('Extracted to:', extract_dir)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Zip exists: True
# Extracted to: /content/drive/MyDrive/MangoSense

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
import json
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import joblib

# ============================================================
# COLAB SETUP — update BASE_DIR if your folder name differs
# ============================================================
def _is_colab():
    try:
        import google.colab  # noqa: F401
        return True
    except ImportError:
        return False

if _is_colab():
    from google.colab import drive
    drive.mount("/content/drive")
    BASE_DIR = "/content/drive/MyDrive/MangoSense"
else:
    BASE_DIR = ""

def p(*parts):
    """Join paths under BASE_DIR (works locally and on Colab)."""
    return os.path.join(BASE_DIR, *parts) if BASE_DIR else os.path.join(*parts)

# ============================================================
# CONFIG
# Images come from the preprocessed directories (already split).
# Symptom features are class-level averages from the CSV —
# no per-image filename matching is needed.
# ============================================================
SYMPTOM_CSV = p("symptom_data", "all_datasets_symptom_features.csv")

META_COLUMNS = {
    "dataset", "split", "class", "filename",
    "filepath", "relative_path", "color_dominant_hue_bin",
}

DATASETS = {
    "leaves": {
        "dataset_filter":  "Leaves_Mixed",
        "data_dir":        p("datasets", "preprocessed-leaves"),
        "save_dir":        p("models-custom-hybrid-leaves-"),
        "img_size":        (240, 240),
        "num_epochs":      50,
        "learning_rate":   1e-3,
        "batch_size":      32,
        "modality_dropout": 0.5,  # leaves are visually distinct — image branch can learn alone
    },
    "fruit": {
        "dataset_filter":  "Mango_Fruits",
        "data_dir":        p("datasets", "preprocessed-fruit-dual"),
        "save_dir":        p("models-custom-hybrid-fruit-final"),
        "img_size":        (240, 240),
        "num_epochs":      60,
        "learning_rate":   1e-3,
        "batch_size":      32,
        "modality_dropout": 0.2,  # fruit is visually subtle — allow symptoms to guide image learning
    },
}


# ============================================================
# Model definition — MangoSenseNet-CoAttn
# ============================================================
_REG = tf.keras.regularizers.l2(1e-4)


def conv_block(x, filters):
    x = tf.keras.layers.Conv2D(
        filters, 3, padding="same", use_bias=False, kernel_regularizer=_REG
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)
    return x


def build_hybrid_model(input_shape, num_symptom_features, num_classes):
    TOKEN_DIM  = 16
    IMG_TOKENS = 16   # 16 × 16 = 256-dim total, matches Dense(256)
    SYM_TOKENS = 4    # 4  × 16 = 64-dim total,  matches Dense(64)
    NUM_HEADS  = 4
    KEY_DIM    = TOKEN_DIM // NUM_HEADS   # = 4

    # --- Image branch ---
    img_input = tf.keras.Input(shape=input_shape, name="image")

    augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal_and_vertical"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.15),
        tf.keras.layers.RandomTranslation(0.1, 0.1),
        tf.keras.layers.RandomContrast(0.2),
        tf.keras.layers.RandomBrightness(0.2),
    ], name="augmentation")

    x = augmentation(img_input)
    x = tf.keras.layers.Rescaling(1.0 / 255.0)(x)
    x = conv_block(x, 32)   # → 120×120×32
    x = conv_block(x, 64)   # → 60×60×64
    x = conv_block(x, 128)  # → 30×30×128
    x = conv_block(x, 256)  # → 15×15×256
    x = tf.keras.layers.GlobalAveragePooling2D(name="image_gap")(x)
    x = tf.keras.layers.Dense(
        IMG_TOKENS * TOKEN_DIM, activation="relu", kernel_regularizer=_REG
    )(x)
    x = tf.keras.layers.Dropout(0.5, name="img_dropout")(x)
    img_tokens = tf.keras.layers.Reshape(
        (IMG_TOKENS, TOKEN_DIM), name="img_tokens"
    )(x)  # (B, 16, 16)

    # --- Symptom branch ---
    sym_input = tf.keras.Input(shape=(num_symptom_features,), name="symptoms")
    s = tf.keras.layers.BatchNormalization()(sym_input)
    s = tf.keras.layers.Dense(
        SYM_TOKENS * TOKEN_DIM, activation="relu", kernel_regularizer=_REG
    )(s)
    s = tf.keras.layers.Dropout(0.3, name="sym_dropout")(s)
    sym_tokens = tf.keras.layers.Reshape(
        (SYM_TOKENS, TOKEN_DIM), name="sym_tokens"
    )(s)  # (B, 4, 16)

    # --- Bi-directional co-attention ---
    # Image tokens query symptom tokens: "which symptoms explain what I see?"
    img_attended = tf.keras.layers.MultiHeadAttention(
        num_heads=NUM_HEADS, key_dim=KEY_DIM, name="img_attends_sym"
    )(query=img_tokens, key=sym_tokens, value=sym_tokens)  # (B, 16, 16)

    # Symptom tokens query image tokens: "which visual features match these symptoms?"
    sym_attended = tf.keras.layers.MultiHeadAttention(
        num_heads=NUM_HEADS, key_dim=KEY_DIM, name="sym_attends_img"
    )(query=sym_tokens, key=img_tokens, value=img_tokens)  # (B, 4, 16)

    # Residual + LayerNorm (standard transformer sub-layer pattern)
    img_out = tf.keras.layers.LayerNormalization(name="img_layernorm")(
        img_tokens + img_attended)  # (B, 16, 16)
    sym_out = tf.keras.layers.LayerNormalization(name="sym_layernorm")(
        sym_tokens + sym_attended)  # (B, 4, 16)

    # --- Fusion head ---
    img_flat = tf.keras.layers.Dropout(0.3)(
        tf.keras.layers.Flatten(name="img_flat")(img_out))  # (B, 256)
    sym_flat = tf.keras.layers.Dropout(0.3)(
        tf.keras.layers.Flatten(name="sym_flat")(sym_out))  # (B, 64)
    fused = tf.keras.layers.Concatenate(name="fusion")([img_flat, sym_flat])  # (B, 320)
    out = tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=_REG)(fused)
    out = tf.keras.layers.Dropout(0.4)(out)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax", name="predictions")(out)

    return tf.keras.Model(
        inputs={"image": img_input, "symptoms": sym_input},
        outputs=outputs,
        name="MangoSenseNet_CoAttn",
    )


# ============================================================
# Symptom feature helpers
# ============================================================
def compute_class_means(df, feature_cols, class_names):
    """Return (num_classes, num_features) array of per-class mean features."""
    means = df.groupby("class")[feature_cols].mean()
    return np.array([
        means.loc[c].values if c in means.index else np.zeros(len(feature_cols))
        for c in class_names
    ], dtype=np.float32)


def attach_class_symptoms(class_feat_tensor, training=False, dropout_rate=0.5):
    """
    Returns a tf.data map fn that attaches class-prototype symptom features.

    During training (training=True), randomly zeros the entire symptom vector
    for each sample with probability `dropout_rate` (modality dropout).
    This prevents the image branch from relying on the prototype as a shortcut
    to the correct class label, forcing it to learn visual features independently.

    During evaluation (training=False), always attaches the class prototype
    (oracle mode — upper bound to show hybrid model potential).
    """
    def _fn(image, label):
        class_idx = tf.argmax(label, axis=-1)
        symptoms  = tf.gather(class_feat_tensor, class_idx)
        if training:
            batch_size = tf.shape(symptoms)[0]
            keep = tf.cast(
                tf.random.uniform([batch_size, 1]) > dropout_rate,
                tf.float32,
            )
            symptoms = symptoms * keep
        return {"image": image, "symptoms": symptoms}, label
    return _fn


def zero_symptoms_fn(num_features):
    """Returns a tf.data map fn that zeros all symptom features (honest baseline)."""
    def _fn(image, label):
        zeros = tf.zeros((tf.shape(image)[0], num_features), dtype=tf.float32)
        return {"image": image, "symptoms": zeros}, label
    return _fn


# ============================================================
# Train each dataset
# ============================================================
all_results = {}

print(f"Loading symptom CSV: {SYMPTOM_CSV}")
df_all = pd.read_csv(SYMPTOM_CSV)
print(f"Total rows: {len(df_all)}")
print(f"Datasets found: {df_all['dataset'].unique().tolist()}")

for dataset, cfg in DATASETS.items():
    dataset_filter   = cfg["dataset_filter"]
    data_dir         = cfg["data_dir"]
    save_dir         = cfg["save_dir"]
    img_size         = cfg["img_size"]
    num_epochs       = cfg["num_epochs"]
    learning_rate    = cfg["learning_rate"]
    batch_size       = cfg["batch_size"]
    modality_dropout = cfg["modality_dropout"]
    input_shape      = (*img_size, 3)

    print(f"\n{'='*55}")
    print(f"  Training MangoSenseNet-CoAttn — {dataset.upper()}")
    print(f"{'='*55}")
    print(f"  LR: {learning_rate}  |  Batch: {batch_size}  |  Epochs: {num_epochs}  |  Modality dropout: {modality_dropout}")
    print(f"  Image dir: {data_dir}")

    if not os.path.isdir(data_dir):
        print(f"  ERROR: Image directory not found: {data_dir}")
        continue

    AUTOTUNE = tf.data.AUTOTUNE

    # Load preprocessed images (already split into train/val/test)
    train_ds_raw = tf.keras.utils.image_dataset_from_directory(
        os.path.join(data_dir, "train"),
        image_size=img_size, batch_size=batch_size,
        label_mode="categorical", shuffle=True, seed=42,
    )
    val_ds_raw = tf.keras.utils.image_dataset_from_directory(
        os.path.join(data_dir, "val"),
        image_size=img_size, batch_size=batch_size,
        label_mode="categorical", shuffle=False,
    )
    test_ds_raw = tf.keras.utils.image_dataset_from_directory(
        os.path.join(data_dir, "test"),
        image_size=img_size, batch_size=batch_size,
        label_mode="categorical", shuffle=False,
    )

    class_names  = train_ds_raw.class_names
    num_classes  = len(class_names)
    print(f"  Classes ({num_classes}): {class_names}")
    print(f"  Model parameters will be shown below ↓")

    # Compute class-mean symptom features from CSV
    df = df_all[df_all["dataset"] == dataset_filter].copy()
    if df.empty:
        print(f"  WARNING: No CSV rows for '{dataset_filter}'. Skipping.")
        continue

    feature_cols = [
        c for c in df.columns
        if c not in META_COLUMNS and pd.api.types.is_numeric_dtype(df[c])
    ]
    df = df.dropna(subset=feature_cols)
    print(f"  Symptom features: {len(feature_cols)}")

    class_means_raw    = compute_class_means(df, feature_cols, class_names)
    scaler             = StandardScaler()
    class_means_scaled = scaler.fit_transform(class_means_raw).astype(np.float32)
    class_feat_tensor  = tf.constant(class_means_scaled)

    print("  Class prototype norms:")
    for i, c in enumerate(class_names):
        print(f"    {c:<22} norm={np.linalg.norm(class_means_scaled[i]):.3f}")

    num_features  = len(feature_cols)
    train_attach  = attach_class_symptoms(class_feat_tensor, training=True,  dropout_rate=modality_dropout)
    oracle_attach = attach_class_symptoms(class_feat_tensor, training=False)
    zero_attach   = zero_symptoms_fn(num_features)

    # Training: modality dropout forces image branch to learn visual features alone
    # Val:      oracle prototype (so val_accuracy measures hybrid performance)
    # Test:     evaluated twice — zero (honest baseline) and oracle (upper bound)
    train_ds = (
        train_ds_raw.cache().shuffle(1000, seed=42)
        .map(train_attach,  num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    )
    val_ds = (
        val_ds_raw.cache()
        .map(oracle_attach, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    )

    # Build and compile model
    model = build_hybrid_model(input_shape, num_features, num_classes)
    model.summary()
    print(f"  Total parameters: {model.count_params():,}")

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    os.makedirs(save_dir, exist_ok=True)
    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss", patience=10, restore_best_weights=True, verbose=1,
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=0.5, patience=4, verbose=1,
        ),
        tf.keras.callbacks.ModelCheckpoint(
            os.path.join(save_dir, "best_model.keras"),
            monitor="val_accuracy", save_best_only=True, verbose=1,
        ),
    ]

    history = model.fit(
        train_ds, validation_data=val_ds,
        epochs=num_epochs, callbacks=callbacks, verbose=1,
    )

    # ── Evaluation ─────────────────────────────────────────────────────────────
    # (A) Zero-symptom — image branch only (honest baseline for thesis)
    test_zero = (
        test_ds_raw.cache()
        .map(zero_attach,   num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    )
    loss_zero, acc_zero = model.evaluate(test_zero, verbose=0)
    print(f"\n  [A] Zero-symptom (image-only baseline):  Acc={acc_zero:.4f}  Loss={loss_zero:.4f}")

    y_pred_zero = np.argmax(model.predict(test_zero, verbose=0), axis=1)
    y_true      = np.argmax(np.concatenate([y.numpy() for _, y in test_zero]), axis=1)

    # (B) Oracle — true class prototype (theoretical upper bound)
    test_oracle = (
        test_ds_raw.cache()
        .map(oracle_attach, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
    )
    loss_oracle, acc_oracle = model.evaluate(test_oracle, verbose=0)
    print(f"  [B] Oracle symptoms (upper bound):       Acc={acc_oracle:.4f}  Loss={loss_oracle:.4f}")
    print(f"      Symptom benefit: +{(acc_oracle - acc_zero)*100:.1f}% vs image-only")

    report = classification_report(y_true, y_pred_zero, target_names=class_names, digits=4)
    print("\nClassification Report (zero-symptom / image-only baseline):")
    print(report)

    # ── Save artifacts ──────────────────────────────────────────────────────────
    model.save(os.path.join(save_dir, "hybrid_cnn.keras"))
    joblib.dump(scaler, os.path.join(save_dir, "symptom_scaler.joblib"))

    with open(os.path.join(save_dir, "feature_columns.json"), "w") as f:
        json.dump(feature_cols, f)

    class_proto = {c: class_means_scaled[i].tolist() for i, c in enumerate(class_names)}
    with open(os.path.join(save_dir, "class_symptom_prototypes.json"), "w") as f:
        json.dump(class_proto, f)

    with open(os.path.join(save_dir, "history.json"), "w") as f:
        json.dump(history.history, f)

    with open(os.path.join(save_dir, "classification_report.txt"), "w") as f:
        f.write(f"Dataset: {dataset}\n")
        f.write(f"Accuracy (zero-symptom / image-only): {acc_zero:.4f}\n")
        f.write(f"Accuracy (oracle / upper bound):      {acc_oracle:.4f}\n")
        f.write(f"Loss     (zero-symptom):              {loss_zero:.4f}\n\n")
        f.write(report)

    # Training curves
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(history.history["accuracy"],     label="Train Accuracy")
    axes[0].plot(history.history["val_accuracy"], label="Val Accuracy")
    axes[0].set_title(f"Accuracy — {dataset}")
    axes[0].set_xlabel("Epoch")
    axes[0].legend()

    axes[1].plot(history.history["loss"],     label="Train Loss")
    axes[1].plot(history.history["val_loss"], label="Val Loss")
    axes[1].set_title(f"Loss — {dataset}")
    axes[1].set_xlabel("Epoch")
    axes[1].legend()

    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, "training_curves.png"), dpi=150)
    plt.show()

    # Confusion matrix (zero-symptom results)
    cm   = confusion_matrix(y_true, y_pred_zero)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    fig, ax = plt.subplots(figsize=(8, 6))
    disp.plot(cmap="Blues", ax=ax)
    plt.title(f"Confusion Matrix — MangoSenseNet-CoAttn ({dataset}, zero-symptom)")
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, "confusion_matrix.png"), dpi=150)
    plt.show()

    all_results[dataset] = {
        "acc_zero":   round(acc_zero,   4),
        "acc_oracle": round(acc_oracle, 4),
        "loss_zero":  round(loss_zero,  4),
    }
    print(f"  Results saved to: {save_dir}")

# ============================================================
# Final summary
# ============================================================
print(f"\n{'='*55}")
print("  FINAL RESULTS — MangoSenseNet-CoAttn")
print(f"{'='*55}")
print(f"  {'Dataset':<10} {'Image-only (A)':<18} {'Oracle / +Symptoms (B)'}")
print(f"  {'-'*52}")
for dataset, res in all_results.items():
    gain = (res['acc_oracle'] - res['acc_zero']) * 100
    print(f"  {dataset:<10} {res['acc_zero']:.4f}             {res['acc_oracle']:.4f}  (+{gain:.1f}%)")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading symptom CSV: /content/drive/MyDrive/MangoSense/symptom_data/all_datasets_symptom_features.csv
# Total rows: 3000
# Datasets found: ['Leaves_Mixed', 'Mango_Fruits']
#
# =======================================================
#   Training MangoSenseNet-CoAttn — LEAVES
# =======================================================
#   LR: 0.001  |  Batch: 32  |  Epochs: 50  |  Modality dropout: 0.5
#   Image dir: /content/drive/MyDrive/MangoSense/datasets/preprocessed-leaves-dual
# Found 1750 files belonging to 5 classes.
# Found 375 files belonging to 5 classes.
# Found 375 files belonging to 5 classes.
#   Classes (5): ['Anthracnose', 'Die Back', 'Healthy', 'Powdery Mildew', 'Sooty Mold']
#   Model parameters will be shown below ↓
#   Symptom features: 43
#   Class prototype norms:
#     Anthracnose            norm=6.363
#     Die Back               norm=7.135
#     Healthy                norm=6.956
#     Powdery Mildew         norm=4.951
#     Sooty Mold             norm=7.121
# Model: "MangoSenseNet_CoAttn"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)  │ (None, 240, 240,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augmentation        │ (None, 240, 240,  │          0 │ image[0][0]       │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_5         │ (None, 240, 240,  │          0 │ augmentation[0][… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 240, 240,  │        864 │ rescaling_5[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │        128 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 120, 120,  │          0 │ activation_20[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 120, 120,  │     18,432 │ max_pooling2d_20… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 60, 60,    │          0 │ activation_21[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 60, 60,    │     73,728 │ max_pooling2d_21… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 30, 30,    │          0 │ activation_22[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 30, 30,    │    294,912 │ max_pooling2d_22… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 30,    │      1,024 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 30, 30,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 15, 15,    │          0 │ activation_23[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ symptoms            │ (None, 43)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_gap           │ (None, 256)       │          0 │ max_pooling2d_23… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 43)        │        172 │ symptoms[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 256)       │     65,792 │ image_gap[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 64)        │      2,816 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_dropout         │ (None, 256)       │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_dropout         │ (None, 64)        │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_tokens          │ (None, 16, 16)    │          0 │ img_dropout[0][0] │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_tokens          │ (None, 4, 16)     │          0 │ sym_dropout[0][0] │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_attends_sym     │ (None, 16, 16)    │      1,088 │ sym_tokens[0][0], │
# │ (MultiHeadAttentio… │                   │            │ img_tokens[0][0], │
# │                     │                   │            │ sym_tokens[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_attends_img     │ (None, 4, 16)     │      1,088 │ img_tokens[0][0], │
# │ (MultiHeadAttentio… │                   │            │ sym_tokens[0][0], │
# │                     │                   │            │ img_tokens[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 16, 16)    │          0 │ img_tokens[0][0], │
# │                     │                   │            │ img_attends_sym[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 4, 16)     │          0 │ sym_tokens[0][0], │
# │                     │                   │            │ sym_attends_img[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_layernorm       │ (None, 16, 16)    │         32 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_layernorm       │ (None, 4, 16)     │         32 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_flat (Flatten)  │ (None, 256)       │          0 │ img_layernorm[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_flat (Flatten)  │ (None, 64)        │          0 │ sym_layernorm[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_27          │ (None, 256)       │          0 │ img_flat[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 64)        │          0 │ sym_flat[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion              │ (None, 320)       │          0 │ dropout_27[0][0], │
# │ (Concatenate)       │                   │            │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 128)       │     41,088 │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_29          │ (None, 128)       │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 5)         │        645 │ dropout_29[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 502,609 (1.92 MB)
#  Trainable params: 501,563 (1.91 MB)
#  Non-trainable params: 1,046 (4.09 KB)
#   Total parameters: 502,609
# Epoch 1/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.3872 - loss: 1.7944
# Epoch 1: val_accuracy improved from None to 0.99200, saving model to /content/drive/MyDrive/MangoSense/models-custom-hybrid-leaves-final/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-hybrid-leaves-final/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 28s 200ms/step - accuracy: 0.5103 - loss: 1.3895 - val_accuracy: 0.9920 - val_loss: 0.2274 - learning_rate: 0.0010
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7141 - loss: 0.8545
# Epoch 2: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.7366 - loss: 0.7935 - val_accuracy: 0.9920 - val_loss: 0.1833 - learning_rate: 0.0010
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7759 - loss: 0.6748
# Epoch 3: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.7886 - loss: 0.6464 - val_accuracy: 0.6000 - val_loss: 0.8214 - learning_rate: 0.0010
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8405 - loss: 0.5443
# Epoch 4: val_accuracy improved from 0.99200 to 1.00000, saving model to /content/drive/MyDrive/MangoSense/models-custom-hybrid-leaves-final/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-hybrid-leaves-final/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.8457 - loss: 0.5172 - val_accuracy: 1.0000 - val_loss: 0.1060 - learning_rate: 0.0010
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8747 - loss: 0.4523
# Epoch 5: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.8611 - loss: 0.4716 - val_accuracy: 0.9867 - val_loss: 0.1380 - learning_rate: 0.0010
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8606 - loss: 0.4538
# Epoch 6: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.8543 - loss: 0.4777 - val_accuracy: 1.0000 - val_loss: 0.1079 - learning_rate: 0.0010
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8796 - loss: 0.3901
# Epoch 7: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.8783 - loss: 0.3958 - val_accuracy: 0.9707 - val_loss: 0.1980 - learning_rate: 0.0010
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8727 - loss: 0.4181
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 8: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.8811 - loss: 0.3810 - val_accuracy: 0.9147 - val_loss: 0.2984 - learning_rate: 0.0010
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8950 - loss: 0.3739
# Epoch 9: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.8966 - loss: 0.3598 - val_accuracy: 1.0000 - val_loss: 0.0846 - learning_rate: 5.0000e-04
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8958 - loss: 0.3283
# Epoch 10: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9034 - loss: 0.3191 - val_accuracy: 0.9973 - val_loss: 0.1074 - learning_rate: 5.0000e-04
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9104 - loss: 0.3225
# Epoch 11: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9097 - loss: 0.3232 - val_accuracy: 0.9947 - val_loss: 0.0990 - learning_rate: 5.0000e-04
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9135 - loss: 0.2864
# Epoch 12: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9097 - loss: 0.3069 - val_accuracy: 1.0000 - val_loss: 0.0849 - learning_rate: 5.0000e-04
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9170 - loss: 0.3040
# Epoch 13: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9217 - loss: 0.2851 - val_accuracy: 1.0000 - val_loss: 0.0831 - learning_rate: 5.0000e-04
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9232 - loss: 0.2926
# Epoch 14: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9234 - loss: 0.2782 - val_accuracy: 0.9973 - val_loss: 0.0877 - learning_rate: 5.0000e-04
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9259 - loss: 0.2992
# Epoch 15: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9131 - loss: 0.3066 - val_accuracy: 0.7653 - val_loss: 1.0513 - learning_rate: 5.0000e-04
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9122 - loss: 0.2745
# Epoch 16: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9109 - loss: 0.2854 - val_accuracy: 0.9893 - val_loss: 0.0956 - learning_rate: 5.0000e-04
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9323 - loss: 0.2704
# Epoch 17: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9291 - loss: 0.2703 - val_accuracy: 1.0000 - val_loss: 0.0814 - learning_rate: 5.0000e-04
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9286 - loss: 0.2846
# Epoch 18: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9263 - loss: 0.2744 - val_accuracy: 0.9627 - val_loss: 0.1754 - learning_rate: 5.0000e-04
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9310 - loss: 0.2572
# Epoch 19: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9377 - loss: 0.2437 - val_accuracy: 1.0000 - val_loss: 0.0810 - learning_rate: 5.0000e-04
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9419 - loss: 0.2472
# Epoch 20: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9411 - loss: 0.2448 - val_accuracy: 1.0000 - val_loss: 0.0810 - learning_rate: 5.0000e-04
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9436 - loss: 0.2337
# Epoch 21: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9446 - loss: 0.2341 - val_accuracy: 0.9253 - val_loss: 0.2831 - learning_rate: 5.0000e-04
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9348 - loss: 0.2357
# Epoch 22: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9309 - loss: 0.2558 - val_accuracy: 0.9973 - val_loss: 0.0897 - learning_rate: 5.0000e-04
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9525 - loss: 0.2203
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 23: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9434 - loss: 0.2364 - val_accuracy: 0.9973 - val_loss: 0.0863 - learning_rate: 5.0000e-04
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9491 - loss: 0.2183
# Epoch 24: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9537 - loss: 0.2127 - val_accuracy: 1.0000 - val_loss: 0.0802 - learning_rate: 2.5000e-04
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9500 - loss: 0.2015
# Epoch 25: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9526 - loss: 0.1969 - val_accuracy: 1.0000 - val_loss: 0.0801 - learning_rate: 2.5000e-04
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9632 - loss: 0.1787
# Epoch 26: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9543 - loss: 0.1966 - val_accuracy: 1.0000 - val_loss: 0.0798 - learning_rate: 2.5000e-04
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9616 - loss: 0.1820
# Epoch 27: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9617 - loss: 0.1907 - val_accuracy: 1.0000 - val_loss: 0.0797 - learning_rate: 2.5000e-04
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9508 - loss: 0.2208
# Epoch 28: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9577 - loss: 0.2041 - val_accuracy: 1.0000 - val_loss: 0.0798 - learning_rate: 2.5000e-04
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9647 - loss: 0.1776
# Epoch 29: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9606 - loss: 0.1912 - val_accuracy: 1.0000 - val_loss: 0.0799 - learning_rate: 2.5000e-04
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9521 - loss: 0.2262
# Epoch 30: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9566 - loss: 0.2050 - val_accuracy: 1.0000 - val_loss: 0.0793 - learning_rate: 2.5000e-04
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9694 - loss: 0.1670
# Epoch 31: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9691 - loss: 0.1782 - val_accuracy: 1.0000 - val_loss: 0.0794 - learning_rate: 2.5000e-04
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9691 - loss: 0.1712
# Epoch 32: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9680 - loss: 0.1712 - val_accuracy: 0.9947 - val_loss: 0.0871 - learning_rate: 2.5000e-04
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9621 - loss: 0.1697
# Epoch 33: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9657 - loss: 0.1762 - val_accuracy: 1.0000 - val_loss: 0.0830 - learning_rate: 2.5000e-04
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9698 - loss: 0.1826
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 34: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - accuracy: 0.9651 - loss: 0.1880 - val_accuracy: 1.0000 - val_loss: 0.0797 - learning_rate: 2.5000e-04
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9620 - loss: 0.1734
# Epoch 35: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9657 - loss: 0.1734 - val_accuracy: 1.0000 - val_loss: 0.0790 - learning_rate: 1.2500e-04
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9671 - loss: 0.1753
# Epoch 36: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9669 - loss: 0.1732 - val_accuracy: 1.0000 - val_loss: 0.0784 - learning_rate: 1.2500e-04
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9777 - loss: 0.1462
# Epoch 37: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9771 - loss: 0.1437 - val_accuracy: 1.0000 - val_loss: 0.0783 - learning_rate: 1.2500e-04
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9699 - loss: 0.1535
# Epoch 38: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9737 - loss: 0.1516 - val_accuracy: 1.0000 - val_loss: 0.0782 - learning_rate: 1.2500e-04
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9735 - loss: 0.1496
# Epoch 39: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9754 - loss: 0.1507 - val_accuracy: 1.0000 - val_loss: 0.0784 - learning_rate: 1.2500e-04
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9835 - loss: 0.1360
# Epoch 40: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9806 - loss: 0.1380 - val_accuracy: 1.0000 - val_loss: 0.0780 - learning_rate: 1.2500e-04
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9752 - loss: 0.1554
# Epoch 41: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9754 - loss: 0.1545 - val_accuracy: 1.0000 - val_loss: 0.0778 - learning_rate: 1.2500e-04
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9760 - loss: 0.1445
# Epoch 42: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9771 - loss: 0.1449 - val_accuracy: 1.0000 - val_loss: 0.0777 - learning_rate: 1.2500e-04
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9805 - loss: 0.1299
# Epoch 43: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9783 - loss: 0.1388 - val_accuracy: 1.0000 - val_loss: 0.0796 - learning_rate: 1.2500e-04
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9790 - loss: 0.1350
# Epoch 44: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9749 - loss: 0.1427 - val_accuracy: 1.0000 - val_loss: 0.0775 - learning_rate: 1.2500e-04
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9804 - loss: 0.1283
# Epoch 45: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9800 - loss: 0.1314 - val_accuracy: 1.0000 - val_loss: 0.0773 - learning_rate: 1.2500e-04
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9795 - loss: 0.1382
# Epoch 46: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9783 - loss: 0.1423 - val_accuracy: 1.0000 - val_loss: 0.0772 - learning_rate: 1.2500e-04
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9715 - loss: 0.1589
# Epoch 47: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9760 - loss: 0.1437 - val_accuracy: 0.9973 - val_loss: 0.0897 - learning_rate: 1.2500e-04
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9813 - loss: 0.1288
# Epoch 48: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9817 - loss: 0.1324 - val_accuracy: 0.9973 - val_loss: 0.0825 - learning_rate: 1.2500e-04
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9827 - loss: 0.1372
# Epoch 49: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9834 - loss: 0.1306 - val_accuracy: 1.0000 - val_loss: 0.0769 - learning_rate: 1.2500e-04
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9850 - loss: 0.1202
# Epoch 50: val_accuracy did not improve from 1.00000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9829 - loss: 0.1289 - val_accuracy: 1.0000 - val_loss: 0.0772 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 49.
#
#   [A] Zero-symptom (image-only baseline):  Acc=0.9893  Loss=0.1074
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bfc5c327e20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   [B] Oracle symptoms (upper bound):       Acc=1.0000  Loss=0.0769
#       Symptom benefit: +1.1% vs image-only
#
# Classification Report (zero-symptom / image-only baseline):
#                 precision    recall  f1-score   support
#
#    Anthracnose     1.0000    0.9867    0.9933        75
#       Die Back     1.0000    1.0000    1.0000        75
#        Healthy     0.9868    1.0000    0.9934        75
# Powdery Mildew     1.0000    0.9600    0.9796        75
#     Sooty Mold     0.9615    1.0000    0.9804        75
#
#       accuracy                         0.9893       375
#      macro avg     0.9897    0.9893    0.9893       375
#   weighted avg     0.9897    0.9893    0.9893       375
#   Results saved to: /content/drive/MyDrive/MangoSense/models-custom-hybrid-leaves-final
#
# =======================================================
#   Training MangoSenseNet-CoAttn — FRUIT
# =======================================================
#   LR: 0.001  |  Batch: 32  |  Epochs: 60  |  Modality dropout: 0.2
#   Image dir: /content/drive/MyDrive/MangoSense/datasets/preprocessed-fruit-dual
# Found 350 files belonging to 5 classes.
# Found 75 files belonging to 5 classes.
# Found 75 files belonging to 5 classes.
#   Classes (5): ['Alternaria', 'Anthracnose', 'Black Mold Rot', 'Healthy', 'Stem end Rot']
#   Model parameters will be shown below ↓
#   Symptom features: 43
#   Class prototype norms:
#     Alternaria             norm=3.883
#     Anthracnose            norm=8.410
#     Black Mold Rot         norm=4.799
#     Healthy                norm=8.640
#     Stem end Rot           norm=5.613
# Model: "MangoSenseNet_CoAttn"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)  │ (None, 240, 240,  │          0 │ -                 │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augmentation        │ (None, 240, 240,  │          0 │ image[0][0]       │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_6         │ (None, 240, 240,  │          0 │ augmentation[0][… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 240, 240,  │        864 │ rescaling_6[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 240, 240,  │        128 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 240, 240,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 120, 120,  │          0 │ activation_24[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 120, 120,  │     18,432 │ max_pooling2d_24… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 120, 120,  │        256 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 120, 120,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_25    │ (None, 60, 60,    │          0 │ activation_25[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 60, 60,    │     73,728 │ max_pooling2d_25… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 60, 60,    │        512 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 60, 60,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_26    │ (None, 30, 30,    │          0 │ activation_26[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 30, 30,    │    294,912 │ max_pooling2d_26… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 30,    │      1,024 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 30, 30,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_27    │ (None, 15, 15,    │          0 │ activation_27[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ symptoms            │ (None, 43)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_gap           │ (None, 256)       │          0 │ max_pooling2d_27… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 43)        │        172 │ symptoms[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 256)       │     65,792 │ image_gap[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 64)        │      2,816 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_dropout         │ (None, 256)       │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_dropout         │ (None, 64)        │          0 │ dense_19[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_tokens          │ (None, 16, 16)    │          0 │ img_dropout[0][0] │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_tokens          │ (None, 4, 16)     │          0 │ sym_dropout[0][0] │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_attends_sym     │ (None, 16, 16)    │      1,088 │ sym_tokens[0][0], │
# │ (MultiHeadAttentio… │                   │            │ img_tokens[0][0], │
# │                     │                   │            │ sym_tokens[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_attends_img     │ (None, 4, 16)     │      1,088 │ img_tokens[0][0], │
# │ (MultiHeadAttentio… │                   │            │ sym_tokens[0][0], │
# │                     │                   │            │ img_tokens[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 16, 16)    │          0 │ img_tokens[0][0], │
# │                     │                   │            │ img_attends_sym[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 4, 16)     │          0 │ sym_tokens[0][0], │
# │                     │                   │            │ sym_attends_img[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_layernorm       │ (None, 16, 16)    │         32 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_layernorm       │ (None, 4, 16)     │         32 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_flat (Flatten)  │ (None, 256)       │          0 │ img_layernorm[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sym_flat (Flatten)  │ (None, 64)        │          0 │ sym_layernorm[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 256)       │          0 │ img_flat[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 64)        │          0 │ sym_flat[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion              │ (None, 320)       │          0 │ dropout_32[0][0], │
# │ (Concatenate)       │                   │            │ dropout_33[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 128)       │     41,088 │ fusion[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 128)       │          0 │ dense_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 5)         │        645 │ dropout_34[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 502,609 (1.92 MB)
#  Trainable params: 501,563 (1.91 MB)
#  Non-trainable params: 1,046 (4.09 KB)
#   Total parameters: 502,609
# Epoch 1/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.2842 - loss: 2.2893
# Epoch 1: val_accuracy improved from None to 1.00000, saving model to /content/drive/MyDrive/MangoSense/models-custom-hybrid-fruit-final/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-hybrid-fruit-final/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 12s 264ms/step - accuracy: 0.3514 - loss: 1.9628 - val_accuracy: 1.0000 - val_loss: 0.4636 - learning_rate: 0.0010
# Epoch 2/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6177 - loss: 1.0479
# Epoch 2: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.6514 - loss: 0.9979 - val_accuracy: 1.0000 - val_loss: 0.3366 - learning_rate: 0.0010
# Epoch 3/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7723 - loss: 0.7303
# Epoch 3: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.7600 - loss: 0.7193 - val_accuracy: 1.0000 - val_loss: 0.1780 - learning_rate: 0.0010
# Epoch 4/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7775 - loss: 0.7307
# Epoch 4: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.8000 - loss: 0.6454 - val_accuracy: 1.0000 - val_loss: 0.1450 - learning_rate: 0.0010
# Epoch 5/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7989 - loss: 0.6539
# Epoch 5: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 177ms/step - accuracy: 0.8229 - loss: 0.5887 - val_accuracy: 1.0000 - val_loss: 0.1491 - learning_rate: 0.0010
# Epoch 6/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8458 - loss: 0.5794
# Epoch 6: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.8629 - loss: 0.5216 - val_accuracy: 1.0000 - val_loss: 0.1139 - learning_rate: 0.0010
# Epoch 7/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8883 - loss: 0.4981
# Epoch 7: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.8857 - loss: 0.4686 - val_accuracy: 1.0000 - val_loss: 0.1126 - learning_rate: 0.0010
# Epoch 8/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8206 - loss: 0.6049
# Epoch 8: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8743 - loss: 0.5007 - val_accuracy: 1.0000 - val_loss: 0.2151 - learning_rate: 0.0010
# Epoch 9/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8599 - loss: 0.4543
# Epoch 9: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.8543 - loss: 0.4681 - val_accuracy: 0.9733 - val_loss: 0.2387 - learning_rate: 0.0010
# Epoch 10/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8931 - loss: 0.4640
# Epoch 10: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.8743 - loss: 0.4801 - val_accuracy: 1.0000 - val_loss: 0.1951 - learning_rate: 0.0010
# Epoch 11/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8519 - loss: 0.4561
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.8743 - loss: 0.3945 - val_accuracy: 1.0000 - val_loss: 0.2071 - learning_rate: 0.0010
# Epoch 12/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8718 - loss: 0.4589
# Epoch 12: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.8829 - loss: 0.4272 - val_accuracy: 0.9600 - val_loss: 0.2385 - learning_rate: 5.0000e-04
# Epoch 13/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8680 - loss: 0.4775
# Epoch 13: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - accuracy: 0.9086 - loss: 0.3580 - val_accuracy: 0.9600 - val_loss: 0.2642 - learning_rate: 5.0000e-04
# Epoch 14/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9072 - loss: 0.3685
# Epoch 14: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.9029 - loss: 0.3583 - val_accuracy: 0.9600 - val_loss: 0.2600 - learning_rate: 5.0000e-04
# Epoch 15/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9059 - loss: 0.3157
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 15: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - accuracy: 0.9086 - loss: 0.3309 - val_accuracy: 0.9600 - val_loss: 0.2515 - learning_rate: 5.0000e-04
# Epoch 16/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8892 - loss: 0.3796
# Epoch 16: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.9171 - loss: 0.3118 - val_accuracy: 0.9467 - val_loss: 0.2743 - learning_rate: 2.5000e-04
# Epoch 17/60
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8977 - loss: 0.3671
# Epoch 17: val_accuracy did not improve from 1.00000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.9029 - loss: 0.3519 - val_accuracy: 0.8933 - val_loss: 0.3013 - learning_rate: 2.5000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.
#
#   [A] Zero-symptom (image-only baseline):  Acc=0.2000  Loss=3.0284
#   [B] Oracle symptoms (upper bound):       Acc=1.0000  Loss=0.1117
#       Symptom benefit: +80.0% vs image-only
#
# Classification Report (zero-symptom / image-only baseline):
#                 precision    recall  f1-score   support
#
#     Alternaria     0.0000    0.0000    0.0000        15
#    Anthracnose     0.0000    0.0000    0.0000        15
# Black Mold Rot     0.2000    1.0000    0.3333        15
#        Healthy     0.0000    0.0000    0.0000        15
#   Stem end Rot     0.0000    0.0000    0.0000        15
#
#       accuracy                         0.2000        75
#      macro avg     0.0400    0.2000    0.0667        75
#   weighted avg     0.0400    0.2000    0.0667        75
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#   Results saved to: /content/drive/MyDrive/MangoSense/models-custom-hybrid-fruit-final
#
# =======================================================
#   FINAL RESULTS — MangoSenseNet-CoAttn
# =======================================================
#   Dataset    Image-only (A)     Oracle / +Symptoms (B)
#   ----------------------------------------------------
#   leaves     0.9893             1.0000  (+1.1%)
#   fruit      0.2000             1.0000  (+80.0%)

# %% [markdown]
# CUSTOM CNN BASE MODEL

# %%
import tensorflow as tf
import numpy as np
import os
import json
import argparse
import sys
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# ============================================================
# CONFIG
# ============================================================
DATASETS = {
    "leaves": {
        "data_dir":      "datasets/preprocessed-leaves-dual",
        "save_dir":      "models-custom-cnn-leaves",
        "img_size":      (240, 240),
        "num_epochs":    50,
        "learning_rate": 1e-3,
        "batch_size":    32,
    },
    "fruit": {
        "data_dir":      "datasets/preprocessed-fruit-dual",
        "save_dir":      "models-custom-cnn-fruit",
        "img_size":      (240, 240),
        "num_epochs":    50,
        "learning_rate": 1e-3,
        "batch_size":    32,
    },
}

COLAB_BASE_DIR_CANDIDATES = [
    "/content/drive/MyDrive/MangoSense",
    "/content/drive/MyDrive/MangoSenseFinalDefense",
    "/content/MangoSenseFinalDefense",
]


def running_in_colab():
    return "google.colab" in sys.modules


def parse_args():
    parser = argparse.ArgumentParser(
        description="Train MangoSenseNet-Base on leaves and fruit datasets."
    )
    parser.add_argument(
        "--base-dir",
        default=".",
        help="Project root path. Dataset and model paths are resolved relative to this directory.",
    )
    parser.add_argument(
        "--mount-drive",
        action="store_true",
        help="Mount Google Drive first (only used in Colab).",
    )
    parser.add_argument(
        "--drive-mount-point",
        default="/content/drive",
        help="Drive mount point used in Colab.",
    )
    parser.add_argument(
        "--epochs",
        type=int,
        default=None,
        help="Optional epoch override for both datasets.",
    )

    # Jupyter/Colab injects arguments like "-f <kernel.json>".
    args, unknown = parser.parse_known_args()
    if unknown:
        print(f"Ignoring unknown arguments: {unknown}")
    return args


def maybe_mount_google_drive(args):
    if not args.mount_drive:
        return
    if not running_in_colab():
        print("WARNING: --mount-drive was set, but this runtime is not Colab. Skipping mount.")
        return

    from google.colab import drive  # type: ignore

    drive.mount(args.drive_mount_point)


def resolve_path(base_dir, relative_path):
    if os.path.isabs(relative_path):
        return relative_path
    return os.path.normpath(os.path.join(base_dir, relative_path))


def resolve_base_dir(args):
    # If user explicitly provided a value, respect it.
    if args.base_dir != ".":
        return os.path.abspath(args.base_dir)

    # In Colab, prefer known project locations when available.
    if running_in_colab():
        for candidate in COLAB_BASE_DIR_CANDIDATES:
            if os.path.isdir(candidate):
                print(f"Auto-detected Colab base directory: {candidate}")
                return candidate

    return os.path.abspath(args.base_dir)


# ============================================================
# Model definition — MangoSenseNet-Base
# ============================================================
_REG = tf.keras.regularizers.l2(1e-4)


def conv_block(x, filters):
    x = tf.keras.layers.Conv2D(
        filters, 3, padding="same", use_bias=False, kernel_regularizer=_REG
    )(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.MaxPooling2D(2)(x)
    return x


def build_custom_cnn(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape, name="image")

    augmentation = tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal_and_vertical"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.15),
        tf.keras.layers.RandomTranslation(0.1, 0.1),
        tf.keras.layers.RandomContrast(0.2),
        tf.keras.layers.RandomBrightness(0.2),
    ], name="augmentation")

    x = augmentation(inputs)
    x = tf.keras.layers.Rescaling(1.0 / 255.0)(x)

    x = conv_block(x, 32)   # → 120×120×32
    x = conv_block(x, 64)   # → 60×60×64
    x = conv_block(x, 128)  # → 30×30×128
    x = conv_block(x, 256)  # → 15×15×256

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(256, activation="relu", kernel_regularizer=_REG)(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax", name="predictions")(x)

    return tf.keras.Model(inputs, outputs, name="MangoSenseNet_Base")


def main():
    args = parse_args()
    maybe_mount_google_drive(args)
    base_dir = resolve_base_dir(args)

    print(f"Running in Colab: {running_in_colab()}")
    print(f"Base directory: {base_dir}")

    # ============================================================
    # Train each dataset
    # ============================================================
    all_results = {}

    for dataset, cfg in DATASETS.items():
        data_dir      = resolve_path(base_dir, cfg["data_dir"])
        save_dir      = resolve_path(base_dir, cfg["save_dir"])
        img_size      = cfg["img_size"]
        num_epochs    = args.epochs if args.epochs is not None else cfg["num_epochs"]
        learning_rate = cfg["learning_rate"]
        batch_size    = cfg["batch_size"]
        input_shape   = (*img_size, 3)

        required_dirs = [
            os.path.join(data_dir, "train"),
            os.path.join(data_dir, "val"),
            os.path.join(data_dir, "test"),
        ]
        missing_dirs = [p for p in required_dirs if not os.path.isdir(p)]
        if missing_dirs:
            print(f"\nERROR: Missing dataset directories for '{dataset}'.")
            for missing in missing_dirs:
                print(f"  - {missing}")
            print("Skipping this dataset.")
            continue

        print(f"\n{'='*55}")
        print(f"  Training MangoSenseNet-Base — {dataset.upper()}")
        print(f"{'='*55}")
        print(f"  LR: {learning_rate}  |  Batch: {batch_size}  |  Epochs: {num_epochs}")

        AUTOTUNE = tf.data.AUTOTUNE

        train_ds = tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir, "train"),
            image_size=img_size, batch_size=batch_size,
            label_mode="categorical", shuffle=True, seed=42,
        )
        val_ds = tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir, "val"),
            image_size=img_size, batch_size=batch_size,
            label_mode="categorical", shuffle=False, seed=42,
        )
        test_ds = tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir, "test"),
            image_size=img_size, batch_size=batch_size,
            label_mode="categorical", shuffle=False, seed=42,
        )

        class_names = train_ds.class_names
        num_classes = len(class_names)
        print(f"  Classes ({num_classes}): {class_names}")

        train_ds = train_ds.cache().shuffle(1000, seed=42).prefetch(AUTOTUNE)
        val_ds   = val_ds.cache().prefetch(AUTOTUNE)
        test_ds  = test_ds.cache().prefetch(AUTOTUNE)

        model = build_custom_cnn(input_shape, num_classes)
        model.summary()
        print(f"  Total parameters: {model.count_params():,}")

        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate),
            loss="categorical_crossentropy",
            metrics=["accuracy"],
        )

        os.makedirs(save_dir, exist_ok=True)
        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor="val_loss", patience=10, restore_best_weights=True, verbose=1,
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor="val_loss", factor=0.5, patience=4, verbose=1,
            ),
            tf.keras.callbacks.ModelCheckpoint(
                os.path.join(save_dir, "best_model.keras"),
                monitor="val_accuracy", save_best_only=True, verbose=1,
            ),
        ]

        history = model.fit(
            train_ds, validation_data=val_ds,
            epochs=num_epochs, callbacks=callbacks, verbose=1,
        )

        test_loss, test_acc = model.evaluate(test_ds, verbose=0)
        print(f"\n  Test Accuracy : {test_acc:.4f}")
        print(f"  Test Loss     : {test_loss:.4f}")

        y_true        = np.concatenate([y.numpy() for _, y in test_ds])
        y_true_labels = np.argmax(y_true, axis=1)
        y_pred_probs  = model.predict(test_ds, verbose=0)
        y_pred_labels = np.argmax(y_pred_probs, axis=1)

        report = classification_report(y_true_labels, y_pred_labels, target_names=class_names, digits=4)
        print("\nClassification Report:")
        print(report)

        model.save(os.path.join(save_dir, "custom_cnn.keras"))

        with open(os.path.join(save_dir, "history.json"), "w") as f:
            json.dump(history.history, f)

        with open(os.path.join(save_dir, "classification_report.txt"), "w") as f:
            f.write(f"Dataset: {dataset}\n")
            f.write(f"Test Accuracy: {test_acc:.4f}\n")
            f.write(f"Test Loss: {test_loss:.4f}\n\n")
            f.write(report)

        fig, axes = plt.subplots(1, 2, figsize=(12, 4))
        axes[0].plot(history.history["accuracy"], label="Train Accuracy")
        axes[0].plot(history.history["val_accuracy"], label="Val Accuracy")
        axes[0].set_title(f"Accuracy — {dataset}")
        axes[0].set_xlabel("Epoch")
        axes[0].legend()

        axes[1].plot(history.history["loss"], label="Train Loss")
        axes[1].plot(history.history["val_loss"], label="Val Loss")
        axes[1].set_title(f"Loss — {dataset}")
        axes[1].set_xlabel("Epoch")
        axes[1].legend()

        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, "training_curves.png"), dpi=150)
        plt.show()

        cm   = confusion_matrix(y_true_labels, y_pred_labels)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
        fig, ax = plt.subplots(figsize=(8, 6))
        disp.plot(cmap="Blues", ax=ax)
        plt.title(f"Confusion Matrix — MangoSenseNet-Base ({dataset})")
        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, "confusion_matrix.png"), dpi=150)
        plt.show()

        all_results[dataset] = {"test_accuracy": round(test_acc, 4), "test_loss": round(test_loss, 4)}
        print(f"  Results saved to: {save_dir}")

    # ============================================================
    # Final summary
    # ============================================================
    print(f"\n{'='*40}")
    print("  FINAL RESULTS — MangoSenseNet-Base")
    print(f"{'='*40}")
    for dataset, res in all_results.items():
        print(f"  {dataset:<8} Accuracy: {res['test_accuracy']:.4f}  Loss: {res['test_loss']:.4f}")

    if not all_results:
        print("No training runs were completed. Verify --base-dir and dataset folder structure.")


if __name__ == "__main__":
    main()
# Out:
# Ignoring unknown arguments: ['-f', '/root/.local/share/jupyter/runtime/kernel-44e3eb4d-57f4-4e1a-951e-7f172cff9e1e.json']
# Auto-detected Colab base directory: /content/drive/MyDrive/MangoSense
# Running in Colab: True
# Base directory: /content/drive/MyDrive/MangoSense
#
# =======================================================
#   Training MangoSenseNet-Base — LEAVES
# =======================================================
#   LR: 0.001  |  Batch: 32  |  Epochs: 50
# Found 1750 files belonging to 5 classes.
# Found 375 files belonging to 5 classes.
# Found 375 files belonging to 5 classes.
#   Classes (5): ['Anthracnose', 'Die Back', 'Healthy', 'Powdery Mildew', 'Sooty Mold']
# Model: "MangoSenseNet_Base"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 240, 240, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 240, 240, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_9 (Rescaling)         │ (None, 240, 240, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 240, 240, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 240, 240, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_36 (Activation)      │ (None, 240, 240, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_36 (MaxPooling2D) │ (None, 120, 120, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 120, 120, 64)   │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 120, 120, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_37 (Activation)      │ (None, 120, 120, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_37 (MaxPooling2D) │ (None, 60, 60, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 60, 60, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_38 (Activation)      │ (None, 60, 60, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_38 (MaxPooling2D) │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 30, 30, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 30, 30, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_39 (Activation)      │ (None, 30, 30, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_39 (MaxPooling2D) │ (None, 15, 15, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_49 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 456,933 (1.74 MB)
#  Trainable params: 455,973 (1.74 MB)
#  Non-trainable params: 960 (3.75 KB)
#   Total parameters: 456,933
# Epoch 1/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5676 - loss: 1.1424
# Epoch 1: val_accuracy improved from None to 0.20000, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 29s 184ms/step - accuracy: 0.6989 - loss: 0.8679 - val_accuracy: 0.2000 - val_loss: 1.7961 - learning_rate: 0.0010
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8295 - loss: 0.5683
# Epoch 2: val_accuracy did not improve from 0.20000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.8331 - loss: 0.5311 - val_accuracy: 0.1760 - val_loss: 2.3141 - learning_rate: 0.0010
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8628 - loss: 0.4295
# Epoch 3: val_accuracy did not improve from 0.20000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.8840 - loss: 0.3963 - val_accuracy: 0.1253 - val_loss: 3.6245 - learning_rate: 0.0010
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8900 - loss: 0.3429
# Epoch 4: val_accuracy did not improve from 0.20000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9029 - loss: 0.3299 - val_accuracy: 0.2000 - val_loss: 4.0117 - learning_rate: 0.0010
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9169 - loss: 0.2957
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 5: val_accuracy did not improve from 0.20000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.9034 - loss: 0.3322 - val_accuracy: 0.2000 - val_loss: 3.3873 - learning_rate: 0.0010
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9252 - loss: 0.2654
# Epoch 6: val_accuracy did not improve from 0.20000
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.9246 - loss: 0.2547 - val_accuracy: 0.2000 - val_loss: 3.9795 - learning_rate: 5.0000e-04
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9319 - loss: 0.2343
# Epoch 7: val_accuracy improved from 0.20000 to 0.21867, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.9354 - loss: 0.2239 - val_accuracy: 0.2187 - val_loss: 4.0076 - learning_rate: 5.0000e-04
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9447 - loss: 0.2149
# Epoch 8: val_accuracy improved from 0.21867 to 0.29067, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9463 - loss: 0.2114 - val_accuracy: 0.2907 - val_loss: 2.7844 - learning_rate: 5.0000e-04
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9417 - loss: 0.2121
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 9: val_accuracy improved from 0.29067 to 0.39467, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - accuracy: 0.9446 - loss: 0.2131 - val_accuracy: 0.3947 - val_loss: 2.6506 - learning_rate: 5.0000e-04
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9521 - loss: 0.1967
# Epoch 10: val_accuracy improved from 0.39467 to 0.74400, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9640 - loss: 0.1783 - val_accuracy: 0.7440 - val_loss: 0.5714 - learning_rate: 2.5000e-04
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9702 - loss: 0.1516
# Epoch 11: val_accuracy improved from 0.74400 to 0.82667, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9669 - loss: 0.1557 - val_accuracy: 0.8267 - val_loss: 0.4326 - learning_rate: 2.5000e-04
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9723 - loss: 0.1604
# Epoch 12: val_accuracy did not improve from 0.82667
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9737 - loss: 0.1432 - val_accuracy: 0.8187 - val_loss: 0.4508 - learning_rate: 2.5000e-04
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9723 - loss: 0.1365
# Epoch 13: val_accuracy improved from 0.82667 to 0.94400, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9720 - loss: 0.1411 - val_accuracy: 0.9440 - val_loss: 0.1945 - learning_rate: 2.5000e-04
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9643 - loss: 0.1645
# Epoch 14: val_accuracy did not improve from 0.94400
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9686 - loss: 0.1449 - val_accuracy: 0.8640 - val_loss: 0.3594 - learning_rate: 2.5000e-04
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9743 - loss: 0.1368
# Epoch 15: val_accuracy improved from 0.94400 to 0.96267, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9709 - loss: 0.1350 - val_accuracy: 0.9627 - val_loss: 0.1648 - learning_rate: 2.5000e-04
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9735 - loss: 0.1390
# Epoch 16: val_accuracy did not improve from 0.96267
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9754 - loss: 0.1320 - val_accuracy: 0.9280 - val_loss: 0.2414 - learning_rate: 2.5000e-04
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9826 - loss: 0.1135
# Epoch 17: val_accuracy did not improve from 0.96267
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9777 - loss: 0.1198 - val_accuracy: 0.8933 - val_loss: 0.3364 - learning_rate: 2.5000e-04
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9685 - loss: 0.1368
# Epoch 18: val_accuracy did not improve from 0.96267
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.9674 - loss: 0.1442 - val_accuracy: 0.8987 - val_loss: 0.2621 - learning_rate: 2.5000e-04
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9806 - loss: 0.1145
# Epoch 19: val_accuracy improved from 0.96267 to 0.97867, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9794 - loss: 0.1171 - val_accuracy: 0.9787 - val_loss: 0.1115 - learning_rate: 2.5000e-04
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9835 - loss: 0.1097
# Epoch 20: val_accuracy improved from 0.97867 to 0.98133, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 20: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9789 - loss: 0.1207 - val_accuracy: 0.9813 - val_loss: 0.1051 - learning_rate: 2.5000e-04
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9849 - loss: 0.1077
# Epoch 21: val_accuracy did not improve from 0.98133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9829 - loss: 0.1101 - val_accuracy: 0.9680 - val_loss: 0.1471 - learning_rate: 2.5000e-04
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9868 - loss: 0.1045
# Epoch 22: val_accuracy did not improve from 0.98133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9817 - loss: 0.1092 - val_accuracy: 0.8187 - val_loss: 0.7286 - learning_rate: 2.5000e-04
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9812 - loss: 0.1083
# Epoch 23: val_accuracy did not improve from 0.98133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.9771 - loss: 0.1131 - val_accuracy: 0.9707 - val_loss: 0.1494 - learning_rate: 2.5000e-04
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9875 - loss: 0.1075
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 24: val_accuracy did not improve from 0.98133
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9857 - loss: 0.1008 - val_accuracy: 0.9493 - val_loss: 0.1560 - learning_rate: 2.5000e-04
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9877 - loss: 0.0943
# Epoch 25: val_accuracy improved from 0.98133 to 0.98400, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 25: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9869 - loss: 0.0917 - val_accuracy: 0.9840 - val_loss: 0.1059 - learning_rate: 1.2500e-04
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9901 - loss: 0.0891
# Epoch 26: val_accuracy did not improve from 0.98400
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9914 - loss: 0.0890 - val_accuracy: 0.9813 - val_loss: 0.1026 - learning_rate: 1.2500e-04
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9931 - loss: 0.0806
# Epoch 27: val_accuracy did not improve from 0.98400
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9909 - loss: 0.0838 - val_accuracy: 0.9813 - val_loss: 0.1211 - learning_rate: 1.2500e-04
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9878 - loss: 0.0907
# Epoch 28: val_accuracy did not improve from 0.98400
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9914 - loss: 0.0879 - val_accuracy: 0.9680 - val_loss: 0.1460 - learning_rate: 1.2500e-04
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9918 - loss: 0.0849
# Epoch 29: val_accuracy improved from 0.98400 to 0.98933, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9897 - loss: 0.0880 - val_accuracy: 0.9893 - val_loss: 0.0888 - learning_rate: 1.2500e-04
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9909 - loss: 0.0862
# Epoch 30: val_accuracy did not improve from 0.98933
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9903 - loss: 0.0899 - val_accuracy: 0.9413 - val_loss: 0.2346 - learning_rate: 1.2500e-04
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9865 - loss: 0.0914
# Epoch 31: val_accuracy improved from 0.98933 to 0.99200, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
#
# Epoch 31: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9869 - loss: 0.0916 - val_accuracy: 0.9920 - val_loss: 0.0753 - learning_rate: 1.2500e-04
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9910 - loss: 0.0856
# Epoch 32: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9909 - loss: 0.0860 - val_accuracy: 0.8587 - val_loss: 0.5410 - learning_rate: 1.2500e-04
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9924 - loss: 0.0805
# Epoch 33: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9903 - loss: 0.0853 - val_accuracy: 0.9920 - val_loss: 0.0753 - learning_rate: 1.2500e-04
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9913 - loss: 0.0829
# Epoch 34: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9914 - loss: 0.0827 - val_accuracy: 0.9787 - val_loss: 0.1054 - learning_rate: 1.2500e-04
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9910 - loss: 0.0869
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 35: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9914 - loss: 0.0845 - val_accuracy: 0.9920 - val_loss: 0.0822 - learning_rate: 1.2500e-04
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9927 - loss: 0.0808
# Epoch 36: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9954 - loss: 0.0754 - val_accuracy: 0.9920 - val_loss: 0.0801 - learning_rate: 6.2500e-05
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9948 - loss: 0.0767
# Epoch 37: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9949 - loss: 0.0753 - val_accuracy: 0.9920 - val_loss: 0.0749 - learning_rate: 6.2500e-05
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9966 - loss: 0.0703
# Epoch 38: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.9949 - loss: 0.0761 - val_accuracy: 0.9760 - val_loss: 0.1159 - learning_rate: 6.2500e-05
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9935 - loss: 0.0773
# Epoch 39: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9949 - loss: 0.0729 - val_accuracy: 0.9840 - val_loss: 0.1068 - learning_rate: 6.2500e-05
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9905 - loss: 0.0795
# Epoch 40: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9897 - loss: 0.0788 - val_accuracy: 0.9893 - val_loss: 0.0896 - learning_rate: 6.2500e-05
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9948 - loss: 0.0700
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 41: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9949 - loss: 0.0722 - val_accuracy: 0.9893 - val_loss: 0.0849 - learning_rate: 6.2500e-05
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9921 - loss: 0.0724
# Epoch 42: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9926 - loss: 0.0724 - val_accuracy: 0.9893 - val_loss: 0.0776 - learning_rate: 3.1250e-05
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9938 - loss: 0.0733
# Epoch 43: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9943 - loss: 0.0729 - val_accuracy: 0.9920 - val_loss: 0.0679 - learning_rate: 3.1250e-05
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9951 - loss: 0.0711
# Epoch 44: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - accuracy: 0.9954 - loss: 0.0704 - val_accuracy: 0.9893 - val_loss: 0.0765 - learning_rate: 3.1250e-05
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9955 - loss: 0.0688
# Epoch 45: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9943 - loss: 0.0722 - val_accuracy: 0.9920 - val_loss: 0.0754 - learning_rate: 3.1250e-05
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9918 - loss: 0.0723
# Epoch 46: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9937 - loss: 0.0692 - val_accuracy: 0.9920 - val_loss: 0.0742 - learning_rate: 3.1250e-05
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9937 - loss: 0.0759
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 47: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9954 - loss: 0.0693 - val_accuracy: 0.9920 - val_loss: 0.0735 - learning_rate: 3.1250e-05
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9921 - loss: 0.0770
# Epoch 48: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - accuracy: 0.9949 - loss: 0.0714 - val_accuracy: 0.9920 - val_loss: 0.0693 - learning_rate: 1.5625e-05
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9959 - loss: 0.0697
# Epoch 49: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - accuracy: 0.9949 - loss: 0.0703 - val_accuracy: 0.9920 - val_loss: 0.0734 - learning_rate: 1.5625e-05
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9967 - loss: 0.0686
# Epoch 50: val_accuracy did not improve from 0.99200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - accuracy: 0.9954 - loss: 0.0700 - val_accuracy: 0.9920 - val_loss: 0.0706 - learning_rate: 1.5625e-05
# Restoring model weights from the end of the best epoch: 43.
#
#   Test Accuracy : 1.0000
#   Test Loss     : 0.0555
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#    Anthracnose     1.0000    1.0000    1.0000        75
#       Die Back     1.0000    1.0000    1.0000        75
#        Healthy     1.0000    1.0000    1.0000        75
# Powdery Mildew     1.0000    1.0000    1.0000        75
#     Sooty Mold     1.0000    1.0000    1.0000        75
#
#       accuracy                         1.0000       375
#      macro avg     1.0000    1.0000    1.0000       375
#   weighted avg     1.0000    1.0000    1.0000       375
#   Results saved to: /content/drive/MyDrive/MangoSense/models-custom-cnn-leaves
#
# =======================================================
#   Training MangoSenseNet-Base — FRUIT
# =======================================================
#   LR: 0.001  |  Batch: 32  |  Epochs: 50
# Found 350 files belonging to 5 classes.
# Found 75 files belonging to 5 classes.
# Found 75 files belonging to 5 classes.
#   Classes (5): ['Alternaria', 'Anthracnose', 'Black Mold Rot', 'Healthy', 'Stem end Rot']
# Model: "MangoSenseNet_Base"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 240, 240, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 240, 240, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_10 (Rescaling)        │ (None, 240, 240, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 240, 240, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 240, 240, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_40 (Activation)      │ (None, 240, 240, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_40 (MaxPooling2D) │ (None, 120, 120, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 120, 120, 64)   │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 120, 120, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_41 (Activation)      │ (None, 120, 120, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_41 (MaxPooling2D) │ (None, 60, 60, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 60, 60, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_42 (Activation)      │ (None, 60, 60, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_42 (MaxPooling2D) │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 30, 30, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_50          │ (None, 30, 30, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_43 (Activation)      │ (None, 30, 30, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_43 (MaxPooling2D) │ (None, 15, 15, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 456,933 (1.74 MB)
#  Trainable params: 455,973 (1.74 MB)
#  Non-trainable params: 960 (3.75 KB)
#   Total parameters: 456,933
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4188 - loss: 1.4624
# Epoch 1: val_accuracy improved from None to 0.22667, saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-fruit/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/MangoSense/models-custom-cnn-fruit/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.5057 - loss: 1.2954 - val_accuracy: 0.2267 - val_loss: 1.6472 - learning_rate: 0.0010
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5761 - loss: 1.0612
# Epoch 2: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.6086 - loss: 0.9759 - val_accuracy: 0.2133 - val_loss: 1.6741 - learning_rate: 0.0010
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6898 - loss: 0.8492
# Epoch 3: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.6971 - loss: 0.8635 - val_accuracy: 0.2133 - val_loss: 1.7455 - learning_rate: 0.0010
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6580 - loss: 0.8539
# Epoch 4: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.6600 - loss: 0.8485 - val_accuracy: 0.2000 - val_loss: 2.0064 - learning_rate: 0.0010
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6667 - loss: 0.8494
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 5: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.7257 - loss: 0.7742 - val_accuracy: 0.2000 - val_loss: 2.1376 - learning_rate: 0.0010
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7064 - loss: 0.7117
# Epoch 6: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.7229 - loss: 0.6819 - val_accuracy: 0.2000 - val_loss: 2.2770 - learning_rate: 5.0000e-04
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7269 - loss: 0.6824
# Epoch 7: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.7086 - loss: 0.7054 - val_accuracy: 0.2000 - val_loss: 2.4384 - learning_rate: 5.0000e-04
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7271 - loss: 0.7391
# Epoch 8: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 0.7314 - loss: 0.6854 - val_accuracy: 0.2000 - val_loss: 2.6368 - learning_rate: 5.0000e-04
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7054 - loss: 0.6933
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 9: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.7314 - loss: 0.6731 - val_accuracy: 0.2000 - val_loss: 2.8525 - learning_rate: 5.0000e-04
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7151 - loss: 0.6433
# Epoch 10: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.7371 - loss: 0.6246 - val_accuracy: 0.2000 - val_loss: 3.0162 - learning_rate: 2.5000e-04
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8063 - loss: 0.6034
# Epoch 11: val_accuracy did not improve from 0.22667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.7629 - loss: 0.6204 - val_accuracy: 0.2000 - val_loss: 3.0681 - learning_rate: 2.5000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
#   Test Accuracy : 0.2933
#   Test Loss     : 1.6575
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Report:
#                 precision    recall  f1-score   support
#
#     Alternaria     0.3913    0.6000    0.4737        15
#    Anthracnose     0.0000    0.0000    0.0000        15
# Black Mold Rot     0.0000    0.0000    0.0000        15
#        Healthy     0.2955    0.8667    0.4407        15
#   Stem end Rot     0.0000    0.0000    0.0000        15
#
#       accuracy                         0.2933        75
#      macro avg     0.1374    0.2933    0.1829        75
#   weighted avg     0.1374    0.2933    0.1829        75
#   Results saved to: /content/drive/MyDrive/MangoSense/models-custom-cnn-fruit
#
# ========================================
#   FINAL RESULTS — MangoSenseNet-Base
# ========================================
#   leaves   Accuracy: 1.0000  Loss: 0.0555
#   fruit    Accuracy: 0.2933  Loss: 1.6575

# %% [markdown]
# MOBILENETV2 MODEL

# %%
"""
train-mobilenetv2-colab.py
--------------------------
Fine-tune MobileNetV2 (ImageNet weights) on mango disease datasets.
Used as a transfer-learning comparison baseline against MangoSenseNet models.

Two-phase fine-tuning:
  Phase 1 — Frozen base (10 epochs):  train only the classification head
  Phase 2 — Fine-tune  (40 epochs):   unfreeze top 30 layers, very low LR

Run on Colab:
  # !python /content/drive/MyDrive/MangoSense/Scripts/train-mobilenetv2-colab.py
"""

import tensorflow as tf
import numpy as np
import os
import json
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# ============================================================
# COLAB SETUP — update BASE_DIR if your folder name differs
# ============================================================
def _is_colab():
    try:
        import google.colab  # noqa: F401
        return True
    except ImportError:
        return False

if _is_colab():
    from google.colab import drive
    drive.mount("/content/drive")
    BASE_DIR = "/content/drive/MyDrive/MangoSense"
else:
    BASE_DIR = ""

def p(*parts):
    return os.path.join(BASE_DIR, *parts) if BASE_DIR else os.path.join(*parts)

# ============================================================
# CONFIG
# ============================================================
DATASETS = {
    "leaves": {
        "data_dir":        p("datasets", "preprocessed-leaves"),
        "save_dir":        p("models-mobilenetv2-leaves-2"),
        "img_size":        (224, 224),
        "batch_size":      32,
        "epochs_frozen":   10,
        "epochs_finetune": 40,
        "lr_frozen":       1e-3,
        "lr_finetune":     1e-5,
        "unfreeze_layers": 30,   # number of top MobileNetV2 layers to unfreeze
    },
    "fruit": {
        "data_dir":        p("datasets", "preprocessed-fruit"),
        "save_dir":        p("models-mobilenetv2-fruit-2"),
        "img_size":        (224, 224),
        "batch_size":      32,
        "epochs_frozen":   10,
        "epochs_finetune": 40,
        "lr_frozen":       1e-3,
        "lr_finetune":     1e-5,
        "unfreeze_layers": 30,
    },
}


# ============================================================
# Model builder
# ============================================================
def build_mobilenetv2(img_size, num_classes):
    """
    MobileNetV2 with ImageNet weights + custom classification head.
    Returns (model, base_model) so the base can be unfrozen later.
    """
    base = tf.keras.applications.MobileNetV2(
        input_shape=(*img_size, 3),
        include_top=False,
        weights="imagenet",
    )
    base.trainable = False  # Phase 1: all base layers frozen

    inputs = tf.keras.Input(shape=(*img_size, 3), name="image")

    # Same augmentation as custom models for fair comparison
    x = tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal_and_vertical"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.15),
        tf.keras.layers.RandomTranslation(0.1, 0.1),
        tf.keras.layers.RandomContrast(0.2),
        tf.keras.layers.RandomBrightness(0.2),
    ], name="augmentation")(inputs)

    # MobileNetV2 expects pixel values in [-1, 1]
    x = tf.keras.layers.Rescaling(1 / 127.5, offset=-1, name="preprocess")(x)

    # training=False keeps BatchNorm in inference mode (safe for frozen base)
    x = base(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D(name="gap")(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax", name="predictions")(x)

    model = tf.keras.Model(inputs, outputs, name="MobileNetV2_MangoSense")
    return model, base


def unfreeze_top_layers(base, num_layers):
    """Unfreeze the top `num_layers` of the base; keep all BatchNorm frozen."""
    base.trainable = True
    for layer in base.layers[:-num_layers]:
        layer.trainable = False
    # Keep BatchNorm layers frozen to preserve ImageNet statistics
    for layer in base.layers:
        if isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = False


# ============================================================
# Train each dataset
# ============================================================
all_results = {}

for dataset, cfg in DATASETS.items():
    data_dir        = cfg["data_dir"]
    save_dir        = cfg["save_dir"]
    img_size        = cfg["img_size"]
    batch_size      = cfg["batch_size"]
    epochs_frozen   = cfg["epochs_frozen"]
    epochs_finetune = cfg["epochs_finetune"]
    lr_frozen       = cfg["lr_frozen"]
    lr_finetune     = cfg["lr_finetune"]
    unfreeze_layers = cfg["unfreeze_layers"]

    print(f"\n{'='*55}")
    print(f"  Training MobileNetV2 — {dataset.upper()}")
    print(f"{'='*55}")
    print(f"  Phase 1: {epochs_frozen} epochs frozen  (LR={lr_frozen})")
    print(f"  Phase 2: {epochs_finetune} epochs fine-tune (LR={lr_finetune}, top {unfreeze_layers} layers)")
    print(f"  Image dir: {data_dir}")

    if not os.path.isdir(data_dir):
        print(f"  ERROR: Image directory not found: {data_dir}")
        continue

    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = tf.keras.utils.image_dataset_from_directory(
        os.path.join(data_dir, "train"),
        image_size=img_size, batch_size=batch_size,
        label_mode="categorical", shuffle=True, seed=42,
    )
    val_ds = tf.keras.utils.image_dataset_from_directory(
        os.path.join(data_dir, "val"),
        image_size=img_size, batch_size=batch_size,
        label_mode="categorical", shuffle=False,
    )
    test_ds = tf.keras.utils.image_dataset_from_directory(
        os.path.join(data_dir, "test"),
        image_size=img_size, batch_size=batch_size,
        label_mode="categorical", shuffle=False,
    )

    class_names = train_ds.class_names
    num_classes = len(class_names)
    print(f"  Classes ({num_classes}): {class_names}")

    train_ds = train_ds.cache().shuffle(1000, seed=42).prefetch(AUTOTUNE)
    val_ds   = val_ds.cache().prefetch(AUTOTUNE)
    test_ds  = test_ds.cache().prefetch(AUTOTUNE)

    model, base = build_mobilenetv2(img_size, num_classes)
    model.summary()
    print(f"  Total parameters (phase 1): {model.count_params():,}")

    os.makedirs(save_dir, exist_ok=True)

    # ── Phase 1: frozen base, train head only ──────────────────────────────────
    print(f"\n  ── Phase 1: Training classification head (base frozen) ──")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr_frozen),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    ckpt_path = os.path.join(save_dir, "best_model.keras")
    callbacks_p1 = [
        tf.keras.callbacks.ModelCheckpoint(
            ckpt_path, monitor="val_accuracy", save_best_only=True, verbose=1,
        ),
    ]

    h1 = model.fit(
        train_ds, validation_data=val_ds,
        epochs=epochs_frozen,
        callbacks=callbacks_p1,
        verbose=1,
    )

    # ── Phase 2: unfreeze top layers, fine-tune ────────────────────────────────
    print(f"\n  ── Phase 2: Fine-tuning top {unfreeze_layers} layers ──")
    unfreeze_top_layers(base, unfreeze_layers)
    trainable_count = sum(tf.size(w).numpy() for w in model.trainable_weights)
    print(f"  Trainable parameters (phase 2): {trainable_count:,}")

    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr_finetune),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    callbacks_p2 = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss", patience=10, restore_best_weights=True, verbose=1,
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=0.5, patience=4, verbose=1,
        ),
        tf.keras.callbacks.ModelCheckpoint(
            ckpt_path, monitor="val_accuracy", save_best_only=True, verbose=1,
        ),
    ]

    h2 = model.fit(
        train_ds, validation_data=val_ds,
        initial_epoch=epochs_frozen,
        epochs=epochs_frozen + epochs_finetune,
        callbacks=callbacks_p2,
        verbose=1,
    )

    # ── Evaluation ─────────────────────────────────────────────────────────────
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    print(f"\n  Test Accuracy : {test_acc:.4f}")
    print(f"  Test Loss     : {test_loss:.4f}")

    y_pred_probs  = model.predict(test_ds, verbose=0)
    y_pred_labels = np.argmax(y_pred_probs, axis=1)
    y_true        = np.argmax(
        np.concatenate([y.numpy() for _, y in test_ds]), axis=1
    )

    report = classification_report(y_true, y_pred_labels, target_names=class_names, digits=4)
    print("\nClassification Report:")
    print(report)

    # ── Save artifacts ──────────────────────────────────────────────────────────
    model.save(os.path.join(save_dir, "mobilenetv2.keras"))

    # Merge phase 1 and phase 2 histories for one continuous training curve
    full_history = {
        k: h1.history.get(k, []) + h2.history.get(k, [])
        for k in set(list(h1.history) + list(h2.history))
    }
    with open(os.path.join(save_dir, "history.json"), "w") as f:
        json.dump(full_history, f)

    with open(os.path.join(save_dir, "classification_report.txt"), "w") as f:
        f.write(f"Dataset: {dataset}\n")
        f.write(f"Test Accuracy: {test_acc:.4f}\n")
        f.write(f"Test Loss:     {test_loss:.4f}\n\n")
        f.write(report)

    # Training curves
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(full_history["accuracy"],     label="Train Accuracy")
    axes[0].plot(full_history["val_accuracy"], label="Val Accuracy")
    axes[0].axvline(x=epochs_frozen - 1, color="gray", linestyle="--", label="Fine-tune start")
    axes[0].set_title(f"Accuracy — MobileNetV2 ({dataset})")
    axes[0].set_xlabel("Epoch")
    axes[0].legend()

    axes[1].plot(full_history["loss"],     label="Train Loss")
    axes[1].plot(full_history["val_loss"], label="Val Loss")
    axes[1].axvline(x=epochs_frozen - 1, color="gray", linestyle="--", label="Fine-tune start")
    axes[1].set_title(f"Loss — MobileNetV2 ({dataset})")
    axes[1].set_xlabel("Epoch")
    axes[1].legend()

    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, "training_curves.png"), dpi=150)
    plt.show()

    # Confusion matrix
    cm   = confusion_matrix(y_true, y_pred_labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    fig, ax = plt.subplots(figsize=(8, 6))
    disp.plot(cmap="Blues", ax=ax)
    plt.title(f"Confusion Matrix — MobileNetV2 ({dataset})")
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, "confusion_matrix.png"), dpi=150)
    plt.show()

    all_results[dataset] = {"test_accuracy": round(test_acc, 4), "test_loss": round(test_loss, 4)}
    print(f"  Results saved to: {save_dir}")

# ============================================================
# Final summary
# ============================================================
print(f"\n{'='*45}")
print("  FINAL RESULTS — MobileNetV2")
print(f"{'='*45}")
for dataset, res in all_results.items():
    print(f"  {dataset:<8} Accuracy: {res['test_accuracy']:.4f}  Loss: {res['test_loss']:.4f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# =======================================================
#   Training MobileNetV2 — LEAVES
# =======================================================
#   Phase 1: 10 epochs frozen  (LR=0.001)
#   Phase 2: 40 epochs fine-tune (LR=1e-05, top 30 layers)
#   Image dir: /content/drive/MyDrive/MangoSense/datasets/preprocessed-leaves
# Found 1750 files belonging to 5 classes.
# Found 375 files belonging to 5 classes.
# Found 375 files belonging to 5 classes.
#   Classes (5): ['Anthracnose', 'Die Back', 'Healthy', 'Powdery Mildew', 'Sooty Mold']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "MobileNetV2_MangoSense"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ preprocess (Rescaling)          │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gap (GlobalAveragePooling2D)    │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,587,205 (9.87 MB)
#  Trainable params: 329,221 (1.26 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#   Total parameters (phase 1): 2,587,205
#
#   ── Phase 1: Training classification head (base frozen) ──
# Epoch 1/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7065 - loss: 0.7608
# Epoch 1: val_accuracy improved from None to 0.91200, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1099s 4s/step - accuracy: 0.8411 - loss: 0.4256 - val_accuracy: 0.9120 - val_loss: 0.1984
# Epoch 2/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9373 - loss: 0.1687
# Epoch 2: val_accuracy improved from 0.91200 to 0.96800, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.9463 - loss: 0.1524 - val_accuracy: 0.9680 - val_loss: 0.0831
# Epoch 3/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9543 - loss: 0.1347
# Epoch 3: val_accuracy improved from 0.96800 to 0.98400, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9526 - loss: 0.1356 - val_accuracy: 0.9840 - val_loss: 0.0572
# Epoch 4/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9745 - loss: 0.0824
# Epoch 4: val_accuracy improved from 0.98400 to 0.99467, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9703 - loss: 0.0855 - val_accuracy: 0.9947 - val_loss: 0.0499
# Epoch 5/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9686 - loss: 0.0819
# Epoch 5: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9680 - loss: 0.0821 - val_accuracy: 0.9813 - val_loss: 0.0549
# Epoch 6/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9756 - loss: 0.0665
# Epoch 6: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.9783 - loss: 0.0588 - val_accuracy: 0.9867 - val_loss: 0.0427
# Epoch 7/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9777 - loss: 0.0714
# Epoch 7: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9777 - loss: 0.0649 - val_accuracy: 0.9920 - val_loss: 0.0315
# Epoch 8/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9739 - loss: 0.0654
# Epoch 8: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.9743 - loss: 0.0660 - val_accuracy: 0.9840 - val_loss: 0.0344
# Epoch 9/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9842 - loss: 0.0569
# Epoch 9: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9811 - loss: 0.0625 - val_accuracy: 0.9920 - val_loss: 0.0330
# Epoch 10/10
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9842 - loss: 0.0464
# Epoch 10: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9783 - loss: 0.0606 - val_accuracy: 0.9867 - val_loss: 0.0388
#
#   ── Phase 2: Fine-tuning top 30 layers ──
#   Trainable parameters (phase 2): 1,839,941
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9851 - loss: 0.0420
# Epoch 11: val_accuracy improved from None to 0.99200, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 13s 117ms/step - accuracy: 0.9857 - loss: 0.0414 - val_accuracy: 0.9920 - val_loss: 0.0229 - learning_rate: 1.0000e-05
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9938 - loss: 0.0262
# Epoch 12: val_accuracy improved from 0.99200 to 0.99467, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2/best_model.keras
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.9920 - loss: 0.0303 - val_accuracy: 0.9947 - val_loss: 0.0189 - learning_rate: 1.0000e-05
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9959 - loss: 0.0219
# Epoch 13: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9937 - loss: 0.0249 - val_accuracy: 0.9947 - val_loss: 0.0162 - learning_rate: 1.0000e-05
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9874 - loss: 0.0368
# Epoch 14: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9874 - loss: 0.0341 - val_accuracy: 0.9893 - val_loss: 0.0196 - learning_rate: 1.0000e-05
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9850 - loss: 0.0391
# Epoch 15: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9874 - loss: 0.0330 - val_accuracy: 0.9947 - val_loss: 0.0178 - learning_rate: 1.0000e-05
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9931 - loss: 0.0266
# Epoch 16: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.9897 - loss: 0.0312 - val_accuracy: 0.9920 - val_loss: 0.0250 - learning_rate: 1.0000e-05
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9922 - loss: 0.0226
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 17: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9931 - loss: 0.0208 - val_accuracy: 0.9947 - val_loss: 0.0194 - learning_rate: 1.0000e-05
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9920 - loss: 0.0177
# Epoch 18: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.9943 - loss: 0.0182 - val_accuracy: 0.9947 - val_loss: 0.0159 - learning_rate: 5.0000e-06
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9977 - loss: 0.0112
# Epoch 19: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9949 - loss: 0.0161 - val_accuracy: 0.9920 - val_loss: 0.0214 - learning_rate: 5.0000e-06
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9936 - loss: 0.0199
# Epoch 20: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - accuracy: 0.9937 - loss: 0.0185 - val_accuracy: 0.9947 - val_loss: 0.0172 - learning_rate: 5.0000e-06
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9986 - loss: 0.0087
# Epoch 21: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9954 - loss: 0.0153 - val_accuracy: 0.9920 - val_loss: 0.0200 - learning_rate: 5.0000e-06
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9933 - loss: 0.0215
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 22: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9931 - loss: 0.0209 - val_accuracy: 0.9947 - val_loss: 0.0191 - learning_rate: 5.0000e-06
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9979 - loss: 0.0140
# Epoch 23: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9954 - loss: 0.0209 - val_accuracy: 0.9947 - val_loss: 0.0163 - learning_rate: 2.5000e-06
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9946 - loss: 0.0144
# Epoch 24: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9949 - loss: 0.0135 - val_accuracy: 0.9947 - val_loss: 0.0181 - learning_rate: 2.5000e-06
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9991 - loss: 0.0099
# Epoch 25: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9983 - loss: 0.0106 - val_accuracy: 0.9947 - val_loss: 0.0151 - learning_rate: 2.5000e-06
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9992 - loss: 0.0068
# Epoch 26: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9983 - loss: 0.0111 - val_accuracy: 0.9947 - val_loss: 0.0143 - learning_rate: 2.5000e-06
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9946 - loss: 0.0140
# Epoch 27: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.9966 - loss: 0.0131 - val_accuracy: 0.9947 - val_loss: 0.0139 - learning_rate: 2.5000e-06
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9942 - loss: 0.0172
# Epoch 28: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9960 - loss: 0.0147 - val_accuracy: 0.9947 - val_loss: 0.0126 - learning_rate: 2.5000e-06
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9937 - loss: 0.0211
# Epoch 29: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9954 - loss: 0.0176 - val_accuracy: 0.9920 - val_loss: 0.0162 - learning_rate: 2.5000e-06
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9965 - loss: 0.0161
# Epoch 30: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9960 - loss: 0.0154 - val_accuracy: 0.9947 - val_loss: 0.0135 - learning_rate: 2.5000e-06
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9912 - loss: 0.0210
# Epoch 31: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.9926 - loss: 0.0195 - val_accuracy: 0.9947 - val_loss: 0.0131 - learning_rate: 2.5000e-06
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9983 - loss: 0.0098
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 32: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9977 - loss: 0.0096 - val_accuracy: 0.9947 - val_loss: 0.0125 - learning_rate: 2.5000e-06
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9977 - loss: 0.0115
# Epoch 33: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9971 - loss: 0.0122 - val_accuracy: 0.9947 - val_loss: 0.0123 - learning_rate: 1.2500e-06
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9968 - loss: 0.0103
# Epoch 34: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9971 - loss: 0.0102 - val_accuracy: 0.9947 - val_loss: 0.0116 - learning_rate: 1.2500e-06
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9979 - loss: 0.0117
# Epoch 35: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9966 - loss: 0.0134 - val_accuracy: 0.9947 - val_loss: 0.0125 - learning_rate: 1.2500e-06
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9971 - loss: 0.0099
# Epoch 36: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9966 - loss: 0.0119 - val_accuracy: 0.9947 - val_loss: 0.0120 - learning_rate: 1.2500e-06
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9938 - loss: 0.0123
# Epoch 37: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - accuracy: 0.9954 - loss: 0.0113 - val_accuracy: 0.9947 - val_loss: 0.0107 - learning_rate: 1.2500e-06
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9969 - loss: 0.0104
# Epoch 38: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9971 - loss: 0.0115 - val_accuracy: 0.9947 - val_loss: 0.0119 - learning_rate: 1.2500e-06
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9978 - loss: 0.0060
# Epoch 39: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9977 - loss: 0.0064 - val_accuracy: 0.9947 - val_loss: 0.0109 - learning_rate: 1.2500e-06
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9995 - loss: 0.0050
# Epoch 40: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9989 - loss: 0.0067 - val_accuracy: 0.9947 - val_loss: 0.0123 - learning_rate: 1.2500e-06
# Epoch 41/50
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9978 - loss: 0.0090
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 41: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.9971 - loss: 0.0112 - val_accuracy: 0.9947 - val_loss: 0.0127 - learning_rate: 1.2500e-06
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9990 - loss: 0.0059
# Epoch 42: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9983 - loss: 0.0083 - val_accuracy: 0.9947 - val_loss: 0.0116 - learning_rate: 6.2500e-07
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9979 - loss: 0.0061
# Epoch 43: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9947 - val_loss: 0.0112 - learning_rate: 6.2500e-07
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9992 - loss: 0.0077
# Epoch 44: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9989 - loss: 0.0074 - val_accuracy: 0.9947 - val_loss: 0.0112 - learning_rate: 6.2500e-07
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9970 - loss: 0.0082
# Epoch 45: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9966 - loss: 0.0090 - val_accuracy: 0.9947 - val_loss: 0.0103 - learning_rate: 6.2500e-07
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9995 - loss: 0.0042
# Epoch 46: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9983 - loss: 0.0064 - val_accuracy: 0.9947 - val_loss: 0.0101 - learning_rate: 6.2500e-07
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9971 - loss: 0.0076
# Epoch 47: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9960 - loss: 0.0098 - val_accuracy: 0.9947 - val_loss: 0.0103 - learning_rate: 6.2500e-07
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9972 - loss: 0.0102
# Epoch 48: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.9966 - loss: 0.0106 - val_accuracy: 0.9947 - val_loss: 0.0111 - learning_rate: 6.2500e-07
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9989 - loss: 0.0089
# Epoch 49: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.9977 - loss: 0.0144 - val_accuracy: 0.9947 - val_loss: 0.0118 - learning_rate: 6.2500e-07
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9986 - loss: 0.0059
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 50: val_accuracy did not improve from 0.99467
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9977 - loss: 0.0073 - val_accuracy: 0.9947 - val_loss: 0.0112 - learning_rate: 6.2500e-07
# Restoring model weights from the end of the best epoch: 46.
#
#   Test Accuracy : 1.0000
#   Test Loss     : 0.0024
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#    Anthracnose     1.0000    1.0000    1.0000        75
#       Die Back     1.0000    1.0000    1.0000        75
#        Healthy     1.0000    1.0000    1.0000        75
# Powdery Mildew     1.0000    1.0000    1.0000        75
#     Sooty Mold     1.0000    1.0000    1.0000        75
#
#       accuracy                         1.0000       375
#      macro avg     1.0000    1.0000    1.0000       375
#   weighted avg     1.0000    1.0000    1.0000       375
#   Results saved to: /content/drive/MyDrive/MangoSense/models-mobilenetv2-leaves-2
#
# =======================================================
#   Training MobileNetV2 — FRUIT
# =======================================================
#   Phase 1: 10 epochs frozen  (LR=0.001)
#   Phase 2: 40 epochs fine-tune (LR=1e-05, top 30 layers)
#   Image dir: /content/drive/MyDrive/MangoSense/datasets/preprocessed-fruit
# Found 350 files belonging to 5 classes.
# Found 75 files belonging to 5 classes.
# Found 75 files belonging to 5 classes.
#   Classes (5): ['Alternaria', 'Anthracnose', 'Black Mold Rot', 'Healthy', 'Stem end Rot']
# Model: "MobileNetV2_MangoSense"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ preprocess (Rescaling)          │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gap (GlobalAveragePooling2D)    │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,587,205 (9.87 MB)
#  Trainable params: 329,221 (1.26 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#   Total parameters (phase 1): 2,587,205
#
#   ── Phase 1: Training classification head (base frozen) ──
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.3873 - loss: 1.5809
# Epoch 1: val_accuracy improved from None to 0.64000, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 260s 5s/step - accuracy: 0.4829 - loss: 1.3296 - val_accuracy: 0.6400 - val_loss: 0.7947
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6828 - loss: 0.7792
# Epoch 2: val_accuracy improved from 0.64000 to 0.80000, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.7057 - loss: 0.7482 - val_accuracy: 0.8000 - val_loss: 0.6519
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7664 - loss: 0.6018
# Epoch 3: val_accuracy improved from 0.80000 to 0.81333, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.7714 - loss: 0.6007 - val_accuracy: 0.8133 - val_loss: 0.6247
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7716 - loss: 0.4963
# Epoch 4: val_accuracy did not improve from 0.81333
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.7971 - loss: 0.4890 - val_accuracy: 0.8000 - val_loss: 0.6249
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7813 - loss: 0.5456
# Epoch 5: val_accuracy did not improve from 0.81333
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.8114 - loss: 0.4823 - val_accuracy: 0.8133 - val_loss: 0.6128
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8782 - loss: 0.3922
# Epoch 6: val_accuracy did not improve from 0.81333
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8457 - loss: 0.4218 - val_accuracy: 0.8133 - val_loss: 0.5965
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8610 - loss: 0.3863
# Epoch 7: val_accuracy did not improve from 0.81333
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8714 - loss: 0.3603 - val_accuracy: 0.8000 - val_loss: 0.5783
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8266 - loss: 0.4361
# Epoch 8: val_accuracy did not improve from 0.81333
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8457 - loss: 0.4142 - val_accuracy: 0.8000 - val_loss: 0.5941
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8235 - loss: 0.4235
# Epoch 9: val_accuracy improved from 0.81333 to 0.82667, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.8200 - loss: 0.4024 - val_accuracy: 0.8267 - val_loss: 0.5447
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8492 - loss: 0.4105
# Epoch 10: val_accuracy did not improve from 0.82667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.8714 - loss: 0.3577 - val_accuracy: 0.8000 - val_loss: 0.5546
#
#   ── Phase 2: Fine-tuning top 30 layers ──
#   Trainable parameters (phase 2): 1,839,941
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8008 - loss: 0.4112
# Epoch 11: val_accuracy improved from None to 0.81333, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 10s 340ms/step - accuracy: 0.8171 - loss: 0.3846 - val_accuracy: 0.8133 - val_loss: 0.5294 - learning_rate: 1.0000e-05
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8777 - loss: 0.3425
# Epoch 12: val_accuracy improved from 0.81333 to 0.82667, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.8657 - loss: 0.3441 - val_accuracy: 0.8267 - val_loss: 0.5336 - learning_rate: 1.0000e-05
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8596 - loss: 0.4003
# Epoch 13: val_accuracy improved from 0.82667 to 0.84000, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.8657 - loss: 0.3584 - val_accuracy: 0.8400 - val_loss: 0.5293 - learning_rate: 1.0000e-05
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8844 - loss: 0.2787
# Epoch 14: val_accuracy did not improve from 0.84000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.8857 - loss: 0.2937 - val_accuracy: 0.8267 - val_loss: 0.5439 - learning_rate: 1.0000e-05
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8648 - loss: 0.3440
# Epoch 15: val_accuracy did not improve from 0.84000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.8743 - loss: 0.3320 - val_accuracy: 0.8267 - val_loss: 0.5260 - learning_rate: 1.0000e-05
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8895 - loss: 0.3204
# Epoch 16: val_accuracy did not improve from 0.84000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8886 - loss: 0.3139 - val_accuracy: 0.8400 - val_loss: 0.5341 - learning_rate: 1.0000e-05
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8471 - loss: 0.4087
# Epoch 17: val_accuracy did not improve from 0.84000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.8629 - loss: 0.3647 - val_accuracy: 0.8400 - val_loss: 0.5109 - learning_rate: 1.0000e-05
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8704 - loss: 0.3850
# Epoch 18: val_accuracy did not improve from 0.84000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8943 - loss: 0.3259 - val_accuracy: 0.8400 - val_loss: 0.5209 - learning_rate: 1.0000e-05
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8294 - loss: 0.3801
# Epoch 19: val_accuracy did not improve from 0.84000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8771 - loss: 0.3301 - val_accuracy: 0.8400 - val_loss: 0.5147 - learning_rate: 1.0000e-05
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8898 - loss: 0.3008
# Epoch 20: val_accuracy did not improve from 0.84000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8914 - loss: 0.2934 - val_accuracy: 0.8400 - val_loss: 0.5277 - learning_rate: 1.0000e-05
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8867 - loss: 0.2764
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 21: val_accuracy improved from 0.84000 to 0.85333, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 21: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.8829 - loss: 0.2750 - val_accuracy: 0.8533 - val_loss: 0.5307 - learning_rate: 1.0000e-05
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9222 - loss: 0.2050
# Epoch 22: val_accuracy did not improve from 0.85333
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.8971 - loss: 0.2655 - val_accuracy: 0.8533 - val_loss: 0.5306 - learning_rate: 5.0000e-06
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8777 - loss: 0.2735
# Epoch 23: val_accuracy improved from 0.85333 to 0.86667, saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2/best_model.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8886 - loss: 0.2634 - val_accuracy: 0.8667 - val_loss: 0.5290 - learning_rate: 5.0000e-06
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8977 - loss: 0.2479
# Epoch 24: val_accuracy did not improve from 0.86667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8943 - loss: 0.2597 - val_accuracy: 0.8533 - val_loss: 0.5371 - learning_rate: 5.0000e-06
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9177 - loss: 0.2366
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 25: val_accuracy did not improve from 0.86667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9143 - loss: 0.2446 - val_accuracy: 0.8533 - val_loss: 0.5407 - learning_rate: 5.0000e-06
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9072 - loss: 0.2865
# Epoch 26: val_accuracy did not improve from 0.86667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9114 - loss: 0.2590 - val_accuracy: 0.8533 - val_loss: 0.5422 - learning_rate: 2.5000e-06
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9156 - loss: 0.2317
# Epoch 27: val_accuracy did not improve from 0.86667
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8971 - loss: 0.2601 - val_accuracy: 0.8667 - val_loss: 0.5390 - learning_rate: 2.5000e-06
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 17.
#
#   Test Accuracy : 0.8933
#   Test Loss     : 0.2935
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#     Alternaria     0.8571    0.8000    0.8276        15
#    Anthracnose     0.9375    1.0000    0.9677        15
# Black Mold Rot     0.7500    0.8000    0.7742        15
#        Healthy     1.0000    0.9333    0.9655        15
#   Stem end Rot     0.9333    0.9333    0.9333        15
#
#       accuracy                         0.8933        75
#      macro avg     0.8956    0.8933    0.8937        75
#   weighted avg     0.8956    0.8933    0.8937        75
#   Results saved to: /content/drive/MyDrive/MangoSense/models-mobilenetv2-fruit-2
#
# =============================================
#   FINAL RESULTS — MobileNetV2
# =============================================
#   leaves   Accuracy: 1.0000  Loss: 0.0024
#   fruit    Accuracy: 0.8933  Loss: 0.2935

# %%
"""
test-hybrid-gui-colab.py
------------------------
Interactive GUI for MangoSenseNet-Hybrid in Google Colab.
Uses ipywidgets — run this file with:

    # %run /content/drive/MyDrive/MangoSense/Scripts/test-hybrid-gui-colab.py

Then interact with the widgets that appear below the cell.
"""

import tensorflow as tf
import numpy as np
import json, os, io, joblib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import ipywidgets as widgets
from IPython.display import display, clear_output
from PIL import Image as PILImage

# ============================================================
# COLAB SETUP — update BASE_DIR if your folder name differs
# ============================================================
def _is_colab():
    try:
        import google.colab  # noqa: F401
        return True
    except ImportError:
        return False

if _is_colab():
    from google.colab import drive
    drive.mount("/content/drive")
    BASE_DIR = "/content/drive/MyDrive/MangoSense"
else:
    BASE_DIR = ""

def p(*parts):
    return os.path.join(BASE_DIR, *parts) if BASE_DIR else os.path.join(*parts)

# ============================================================
# MODEL CONFIG
# ============================================================
MODEL_CONFIGS = {
    "Leaf  — 5 classes (Anthracnose, Die Back, Healthy, Powdery Mildew, Sooty Mold)": {
        "model_path":  p("models-mobilenetv2-leaves", "best_model.keras"),
        "proto_path":  p("models-mobilenetv2-leaves", "class_symptom_prototypes.json"),
        "feat_path":   p("models-mobilenetv2-leaves", "feature_columns.json"),
        "img_size":    (240, 240),
    },
    "Fruit — 5 classes (Alternaria, Anthracnose, Black Mold Rot, Healthy, Stem end Rot)": {
        "model_path":  p("models-mobilenetv2-fruit", "best_model.keras"),
        "proto_path":  p("models-mobilenetv2-fruit", "class_symptom_prototypes.json"),
        "feat_path":   p("models-mobilenetv2-fruit", "feature_columns.json"),
        "img_size":    (240, 240),
    },
}

# ============================================================
# Load models at startup
# ============================================================
print("Loading MangoSenseNet-Hybrid models...")
loaded = {}
for label, cfg in MODEL_CONFIGS.items():
    try:
        model = tf.keras.models.load_model(cfg["model_path"])
        with open(cfg["proto_path"]) as f:
            proto_dict = json.load(f)
        with open(cfg["feat_path"]) as f:
            feature_cols = json.load(f)
        loaded[label] = {
            "model":        model,
            "proto_dict":   proto_dict,
            "feature_cols": feature_cols,
            "img_size":     cfg["img_size"],
            "class_names":  sorted(proto_dict.keys()),
        }
        print(f"  ✓ Loaded: {label.split('—')[0].strip()}")
    except Exception as e:
        print(f"  ✗ Failed ({label.split('—')[0].strip()}): {e}")

if not loaded:
    raise RuntimeError("No models loaded. Check your BASE_DIR and model paths.")

# ============================================================
# Prediction helper
# ============================================================
def predict(img_bytes, model_label):
    cfg         = loaded[model_label]
    model       = cfg["model"]
    proto_dict  = cfg["proto_dict"]
    feat_cols   = cfg["feature_cols"]
    class_names = cfg["class_names"]
    img_size    = cfg["img_size"]

    # Decode image from bytes
    pil_img = PILImage.open(io.BytesIO(img_bytes)).convert("RGB")
    pil_img = pil_img.resize(img_size, PILImage.LANCZOS)
    img_arr = np.array(pil_img, dtype=np.float32)
    img_batch = np.expand_dims(img_arr, 0)          # (1, H, W, 3)

    # Pass 1 — zero symptoms (image branch drives initial guess)
    zero_sym  = np.zeros((1, len(feat_cols)), dtype=np.float32)
    probs_p1  = model({"image": img_batch, "symptoms": zero_sym}, training=False).numpy()[0]
    top_class = class_names[int(np.argmax(probs_p1))]

    # Pass 2 — top-class prototype (refine with symptom knowledge)
    proto_vec = np.array([proto_dict[top_class]], dtype=np.float32)
    probs     = model({"image": img_batch, "symptoms": proto_vec}, training=False).numpy()[0]
    pred_idx  = int(np.argmax(probs))

    return pil_img, probs, pred_idx, class_names


def render_result(pil_img, probs, pred_idx, class_names, model_label):
    pred_label = class_names[pred_idx]
    confidence = float(probs[pred_idx]) * 100

    fig, axes = plt.subplots(1, 2, figsize=(13, 5))

    # Left — uploaded image
    axes[0].imshow(pil_img)
    axes[0].set_title("Uploaded Image", fontsize=13, fontweight="bold")
    axes[0].axis("off")

    # Right — probability bar chart
    colors = ["#4CAF50" if i == pred_idx else "#90CAF9" for i in range(len(class_names))]
    bars = axes[1].barh(class_names, probs * 100, color=colors, edgecolor="white", height=0.6)
    axes[1].set_xlim(0, 118)
    axes[1].set_xlabel("Confidence (%)", fontsize=11)
    axes[1].set_title("Prediction Probabilities", fontsize=13, fontweight="bold")
    axes[1].invert_yaxis()

    for bar, prob in zip(bars, probs):
        axes[1].text(
            bar.get_width() + 1.5,
            bar.get_y() + bar.get_height() / 2,
            f"{prob*100:.1f}%", va="center", fontsize=10
        )

    legend = [mpatches.Patch(color="#4CAF50", label=f"Predicted: {pred_label}  ({confidence:.1f}%)")]
    axes[1].legend(handles=legend, loc="lower right", fontsize=11)

    dtype = "Leaf" if "Leaf" in model_label else "Fruit"
    plt.suptitle(
        f"MangoSenseNet-Hybrid  ·  {dtype}  →  {pred_label}",
        fontsize=14, fontweight="bold", y=1.02
    )
    plt.tight_layout()
    plt.show()

    # Text summary
    print(f"\n{'─'*45}")
    print(f"  Prediction : {pred_label}")
    print(f"  Confidence : {confidence:.2f}%")
    print(f"{'─'*45}")
    for cls, prob in zip(class_names, probs):
        bar  = "█" * int(prob * 35)
        mark = " ◀ predicted" if cls == pred_label else ""
        print(f"  {cls:<22} {prob*100:5.1f}%  {bar}{mark}")


# ============================================================
# Widget UI
# ============================================================
title = widgets.HTML(
    value="""
    <div style='background:#1B5E20;padding:14px 20px;border-radius:8px;margin-bottom:8px'>
      <h2 style='color:white;margin:0;font-family:sans-serif'>
        🥭 MangoSenseNet-Hybrid — Disease Detector
      </h2>
      <p style='color:#C8E6C9;margin:4px 0 0;font-size:13px'>
        Upload a mango leaf or fruit image and click Analyze
      </p>
    </div>
    """
)

model_dropdown = widgets.Dropdown(
    options=list(MODEL_CONFIGS.keys()),
    description="",
    layout=widgets.Layout(width="620px"),
    style={"description_width": "0px"},
)

upload_btn = widgets.FileUpload(
    accept="image/*",
    multiple=False,
    description="Upload Image",
    button_style="info",
    layout=widgets.Layout(width="180px"),
)

analyze_btn = widgets.Button(
    description="Analyze",
    button_style="success",
    icon="search",
    layout=widgets.Layout(width="130px", height="36px"),
)

clear_btn = widgets.Button(
    description="Clear",
    button_style="warning",
    icon="times",
    layout=widgets.Layout(width="100px", height="36px"),
)

status_label = widgets.HTML(
    value="<span style='color:gray;font-size:13px'>Upload an image to begin.</span>"
)

output_area = widgets.Output()

# -------- callbacks --------
def on_analyze(b):
    with output_area:
        clear_output(wait=True)

        if not upload_btn.value:
            status_label.value = "<span style='color:red'>⚠ Please upload an image first.</span>"
            return

        model_label = model_dropdown.value
        if model_label not in loaded:
            status_label.value = f"<span style='color:red'>⚠ Model not loaded: {model_label}</span>"
            return

        # Get uploaded file bytes
        uploaded_file = list(upload_btn.value.values())[0]
        img_bytes = uploaded_file["content"]
        fname     = list(upload_btn.value.keys())[0]

        status_label.value = f"<span style='color:#1565C0'>⏳ Analyzing <b>{fname}</b>…</span>"
        analyze_btn.disabled = True

        try:
            pil_img, probs, pred_idx, class_names = predict(img_bytes, model_label)
            render_result(pil_img, probs, pred_idx, class_names, model_label)
            pred_label = class_names[pred_idx]
            conf = float(probs[pred_idx]) * 100
            status_label.value = (
                f"<span style='color:#1B5E20'>✓ Done — "
                f"<b>{pred_label}</b> ({conf:.1f}%)</span>"
            )
        except Exception as e:
            status_label.value = f"<span style='color:red'>Error: {e}</span>"
            print(f"Error during prediction: {e}")
        finally:
            analyze_btn.disabled = False


def on_clear(b):
    with output_area:
        clear_output()
    status_label.value = "<span style='color:gray;font-size:13px'>Cleared. Upload a new image.</span>"


analyze_btn.on_click(on_analyze)
clear_btn.on_click(on_clear)

# -------- layout --------
controls = widgets.HBox(
    [upload_btn, analyze_btn, clear_btn],
    layout=widgets.Layout(gap="10px", align_items="center", margin="8px 0"),
)

ui = widgets.VBox(
    [title, model_dropdown, controls, status_label, output_area],
    layout=widgets.Layout(padding="10px"),
)

display(ui)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading MangoSenseNet-Hybrid models...
#   ✗ Failed (Leaf): 'proto_path'
#   ✗ Failed (Fruit): 'proto_path'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_4820/832669063.py in <cell line: 0>()
#      79
#      80 if not loaded:
# ---> 81     raise RuntimeError("No models loaded. Check your BASE_DIR and model paths.")
#      82
#      83 # ============================================================
#
# RuntimeError: No models loaded. Check your BASE_DIR and model paths.

# %%
"""
test-mobilenetv2-gui-colab.py
------------------------------
Interactive GUI for the fine-tuned MobileNetV2 models in Google Colab.
Uses ipywidgets — run with:

    # %run /content/drive/MyDrive/MangoSense/Scripts/test-mobilenetv2-gui-colab.py
"""

import tensorflow as tf
import numpy as np
import json, os, io
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import ipywidgets as widgets
from IPython.display import display, clear_output
from PIL import Image as PILImage

# ============================================================
# COLAB SETUP
# ============================================================
def _is_colab():
    try:
        import google.colab  # noqa: F401
        return True
    except ImportError:
        return False

if _is_colab():
    from google.colab import drive
    drive.mount("/content/drive")
    BASE_DIR = "/content/drive/MyDrive/MangoSense"
else:
    BASE_DIR = ""

def p(*parts):
    return os.path.join(BASE_DIR, *parts) if BASE_DIR else os.path.join(*parts)

# ============================================================
# MODEL CONFIG
# Class names must match alphabetical order used by
# image_dataset_from_directory during training.
# ============================================================
MODEL_CONFIGS = {
    "Leaf  — 5 classes (Anthracnose, Die Back, Healthy, Powdery Mildew, Sooty Mold)": {
        "model_path":  p("models-mobilenetv2-leaves-2", "best_model.keras"),
        "class_names": ["Anthracnose", "Die Back", "Healthy", "Powdery Mildew", "Sooty Mold"],
        "img_size":    (224, 224),
    },
    "Fruit — 5 classes (Alternaria, Anthracnose, Black Mold Rot, Healthy, Stem end Rot)": {
        "model_path":  p("models-mobilenetv2-fruit-2", "best_model.keras"),
        "class_names": ["Alternaria", "Anthracnose", "Black Mold Rot", "Healthy", "Stem end Rot"],
        "img_size":    (224, 224),
    },
}

# ============================================================
# Load models at startup
# ============================================================
print("Loading MobileNetV2 models...")
loaded = {}
for label, cfg in MODEL_CONFIGS.items():
    try:
        model = tf.keras.models.load_model(cfg["model_path"])
        loaded[label] = {
            "model":       model,
            "class_names": cfg["class_names"],
            "img_size":    cfg["img_size"],
        }
        print(f"  ✓ Loaded: {label.split('—')[0].strip()}")
    except Exception as e:
        print(f"  ✗ Failed ({label.split('—')[0].strip()}): {e}")

if not loaded:
    raise RuntimeError("No models loaded. Check your BASE_DIR and model paths.")

# ============================================================
# Prediction helper
# ============================================================
def predict(img_bytes, model_label):
    cfg         = loaded[model_label]
    model       = cfg["model"]
    class_names = cfg["class_names"]
    img_size    = cfg["img_size"]

    pil_img   = PILImage.open(io.BytesIO(img_bytes)).convert("RGB")
    pil_img   = pil_img.resize(img_size, PILImage.LANCZOS)
    img_arr   = np.array(pil_img, dtype=np.float32)
    img_batch = np.expand_dims(img_arr, 0)   # (1, H, W, 3)

    probs    = model(img_batch, training=False).numpy()[0]
    pred_idx = int(np.argmax(probs))

    return pil_img, probs, pred_idx, class_names


def render_result(pil_img, probs, pred_idx, class_names, model_label):
    pred_label = class_names[pred_idx]
    confidence = float(probs[pred_idx]) * 100

    fig, axes = plt.subplots(1, 2, figsize=(13, 5))

    axes[0].imshow(pil_img)
    axes[0].set_title("Uploaded Image", fontsize=13, fontweight="bold")
    axes[0].axis("off")

    colors = ["#4CAF50" if i == pred_idx else "#90CAF9" for i in range(len(class_names))]
    bars = axes[1].barh(class_names, probs * 100, color=colors, edgecolor="white", height=0.6)
    axes[1].set_xlim(0, 118)
    axes[1].set_xlabel("Confidence (%)", fontsize=11)
    axes[1].set_title("Prediction Probabilities", fontsize=13, fontweight="bold")
    axes[1].invert_yaxis()

    for bar, prob in zip(bars, probs):
        axes[1].text(
            bar.get_width() + 1.5,
            bar.get_y() + bar.get_height() / 2,
            f"{prob*100:.1f}%", va="center", fontsize=10,
        )

    legend = [mpatches.Patch(color="#4CAF50", label=f"Predicted: {pred_label}  ({confidence:.1f}%)")]
    axes[1].legend(handles=legend, loc="lower right", fontsize=11)

    dtype = "Leaf" if "Leaf" in model_label else "Fruit"
    plt.suptitle(
        f"MobileNetV2  ·  {dtype}  →  {pred_label}",
        fontsize=14, fontweight="bold", y=1.02,
    )
    plt.tight_layout()
    plt.show()

    print(f"\n{'─'*45}")
    print(f"  Prediction : {pred_label}")
    print(f"  Confidence : {confidence:.2f}%")
    print(f"{'─'*45}")
    for cls, prob in zip(class_names, probs):
        bar  = "█" * int(prob * 35)
        mark = " ◀ predicted" if cls == pred_label else ""
        print(f"  {cls:<22} {prob*100:5.1f}%  {bar}{mark}")


# ============================================================
# Widget UI
# ============================================================
title = widgets.HTML(
    value="""
    <div style='background:#1A237E;padding:14px 20px;border-radius:8px;margin-bottom:8px'>
      <h2 style='color:white;margin:0;font-family:sans-serif'>
        🥭 MobileNetV2 — Mango Disease Detector
      </h2>
      <p style='color:#C5CAE9;margin:4px 0 0;font-size:13px'>
        Upload a mango leaf or fruit image and click Analyze
      </p>
    </div>
    """
)

model_dropdown = widgets.Dropdown(
    options=list(MODEL_CONFIGS.keys()),
    description="",
    layout=widgets.Layout(width="620px"),
    style={"description_width": "0px"},
)

upload_btn = widgets.FileUpload(
    accept="image/*",
    multiple=False,
    description="Upload Image",
    button_style="info",
    layout=widgets.Layout(width="180px"),
)

analyze_btn = widgets.Button(
    description="Analyze",
    button_style="success",
    icon="search",
    layout=widgets.Layout(width="130px", height="36px"),
)

clear_btn = widgets.Button(
    description="Clear",
    button_style="warning",
    icon="times",
    layout=widgets.Layout(width="100px", height="36px"),
)

status_label = widgets.HTML(
    value="<span style='color:gray;font-size:13px'>Upload an image to begin.</span>"
)

output_area = widgets.Output()


def on_analyze(b):
    with output_area:
        clear_output(wait=True)

        if not upload_btn.value:
            status_label.value = "<span style='color:red'>⚠ Please upload an image first.</span>"
            return

        model_label = model_dropdown.value
        if model_label not in loaded:
            status_label.value = f"<span style='color:red'>⚠ Model not loaded: {model_label}</span>"
            return

        uploaded_file = list(upload_btn.value.values())[0]
        img_bytes = uploaded_file["content"]
        fname     = list(upload_btn.value.keys())[0]

        status_label.value = f"<span style='color:#1565C0'>⏳ Analyzing <b>{fname}</b>…</span>"
        analyze_btn.disabled = True

        try:
            pil_img, probs, pred_idx, class_names = predict(img_bytes, model_label)
            render_result(pil_img, probs, pred_idx, class_names, model_label)
            pred_label = class_names[pred_idx]
            conf = float(probs[pred_idx]) * 100
            status_label.value = (
                f"<span style='color:#1B5E20'>✓ Done — "
                f"<b>{pred_label}</b> ({conf:.1f}%)</span>"
            )
        except Exception as e:
            status_label.value = f"<span style='color:red'>Error: {e}</span>"
            print(f"Error during prediction: {e}")
        finally:
            analyze_btn.disabled = False


def on_clear(b):
    with output_area:
        clear_output()
    status_label.value = "<span style='color:gray;font-size:13px'>Cleared. Upload a new image.</span>"


analyze_btn.on_click(on_analyze)
clear_btn.on_click(on_clear)

controls = widgets.HBox(
    [upload_btn, analyze_btn, clear_btn],
    layout=widgets.Layout(gap="10px", align_items="center", margin="8px 0"),
)

ui = widgets.VBox(
    [title, model_dropdown, controls, status_label, output_area],
    layout=widgets.Layout(padding="10px"),
)

display(ui)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading MobileNetV2 models...
#   ✓ Loaded: Leaf
#   ✓ Loaded: Fruit
# VBox(children=(HTML(value="\n    <div style='background:#1A237E;padding:14px 20px;border-radius:8px;margin-bot…
